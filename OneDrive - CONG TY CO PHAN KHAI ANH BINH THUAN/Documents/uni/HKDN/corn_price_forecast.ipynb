# %% [markdown]
# # Import library and load data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis
from sklearn.preprocessing import MinMaxScaler
from sklearn.neural_network import MLPRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import root_mean_squared_error, r2_score, mean_absolute_error, mean_absolute_percentage_error
from keras.models import Sequential
from keras.layers import LSTM, Dense, Flatten, TimeDistributed, Conv1D, MaxPooling1D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam
from tensorflow.keras.losses import Huber
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("data/corn_price.xlsx")

# %%
df.tail()
# Out:
#            date   close
# 3188 2024-10-04  424.75
# 3189 2024-10-07  426.00
# 3190 2024-10-08  420.75
# 3191 2024-10-09  421.00
# 3192 2024-10-10  418.50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3193 entries, 0 to 3192
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3193 non-null   datetime64[ns]
#  1   close   3193 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 50.0 KB

# %%
fig, ax = plt.subplots(figsize=(20,8))
ax.plot(df['date'], df['close'])
ax.set_xlabel('Ngày')
ax.set_ylabel('Giá')
ax.set_title('Biểu đồ giá bắp theo thời gian')
plt.show()

# %% [markdown]
# # Thống kê mô tả

# %%
df.describe()
# Out:
#                                 date        close
# count                           3193  3193.000000
# mean   2018-05-31 11:28:39.386157312   472.339806
# min              2012-01-24 00:00:00   312.000000
# 25%              2015-03-25 00:00:00   371.000000
# 50%              2018-05-24 00:00:00   420.500000
# 75%              2021-08-10 00:00:00   561.500000
# max              2024-10-10 00:00:00   838.750000
# std                              NaN   130.038973

# %%
df.duplicated().sum()
# Out:
# 0

# %%
fig, ax = plt.subplots(figsize=(8,2))
sns.boxplot(x=df['close'])
ax.set_title('Box plot giá bắp')
plt.show()

# %%
mean = df['close'].mean()
std_dev = df['close'].std()
df['z_score'] = (df['close'] - mean) / std_dev

# Xác định giá trị ngoại lệ
threshold = 3
outliers = df[(df['z_score'] > threshold) | (df['z_score'] < -threshold)]

print("Các dòng giá trị ngoại lệ:")
print(outliers)
# Out:
# Các dòng giá trị ngoại lệ:
# Empty DataFrame
# Columns: [date, close, z_score]
# Index: []

# %%
mean = np.mean(df['close']).round(3)
mode = list(df['close'].mode().round(3))
median = np.median(df['close']).round(3)
data_range = np.ptp(df['close'])
variance = np.var(df['close'], ddof=1).round(3)
std_deviation = np.std(df['close'], ddof=1).round(3)
skewness = skew(df['close']).round(2)
kurt = kurtosis(df['close']).round(2)
print(f'Các đại lượng về xu thế trung tâm của giá bắp')
print(f'Mean: {mean}')
print(f'Mode: {mode}')
print(f'Median: {median}')
print('')
print(f'Các đại lượng về độ phân tán của giá bắp')
print(f'Khoảng biến thiên (Range): {data_range}')
print(f'Phương sai (Variance): {variance}')
print(f'Độ lệch chuẩn (Standard deviation): {std_deviation}')
print('')
print(f'Các đại lượng về hình dáng phân phối của giá bắp')
print(f'Độ lệch: {skewness}')
print(f'Độ nhọn: {kurt}')
# Out:
# Các đại lượng về xu thế trung tâm của giá bắp
# Mean: 472.34
# Mode: [368.25, 373.25, 377.25]
# Median: 420.5
#
# Các đại lượng về độ phân tán của giá bắp
# Khoảng biến thiên (Range): 526.75
# Phương sai (Variance): 16910.134
# Độ lệch chuẩn (Standard deviation): 130.039
#
# Các đại lượng về hình dáng phân phối của giá bắp
# Độ lệch: 0.93
# Độ nhọn: -0.37

# %%
plt.figure(figsize=(8,2))
sns.displot(df['close'], kde = True)
plt.title(f'Phân phối của giá bắp',fontsize = 16)
plt.xlabel('Giá',fontsize = 16)
plt.ylabel('Density',fontsize = 16)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.tight_layout()
plt.show()

# %% [markdown]
# # LSTM

# %% [markdown]
# ## Class CNNLSTMPredictor

# %%
class CNNLSTMPredictor:
    def __init__(self, n_steps=10, n_seq=2, n_features=1):
        self.n_steps = n_steps
        self.n_seq = n_seq
        self.n_features = n_features
        self.scaler = MinMaxScaler()

# Tiền xử lý trước khi đưa dữ liệu vào mô hình
    def create_sequences(self, data):
        length = len(data)
        X = np.array([data[i:i+self.n_steps] for i in range(length-self.n_steps)])
        y = np.array([data[i+self.n_steps] for i in range(length-self.n_steps)])
        # Reshape X to (samples, n_seq, timesteps_per_seq, features)
        return X.reshape((X.shape[0], self.n_seq, self.n_steps//self.n_seq, self.n_features)), y
    
    def prepare_data(self, df, train_size=0.7, val_size=0.15):
        """Prepare and split data into train, validation and test sets"""
        
        # Xử lý cột ngày
        df['date'] = pd.to_datetime(df['date'])
        df = df.sort_values('date')
        
        # Xử lý cột giá
        prices = df['close'].values.reshape(-1, 1)
        scaled_prices = self.scaler.fit_transform(prices)
        
        X, y = self.create_sequences(scaled_prices)
        
        # Chia dữ liệu thành tập train, validation, test
        train_end = int(len(X) * train_size)
        val_end = int(len(X) * (train_size + val_size))
        
        self.X_train, self.y_train = X[:train_end], y[:train_end]
        self.X_val, self.y_val = X[train_end:val_end], y[train_end:val_end]
        self.X_test, self.y_test = X[val_end:], y[val_end:]
        
        self.dates = df['date'].values[self.n_steps:]
        self.train_dates = self.dates[:train_end]
        self.val_dates = self.dates[train_end:val_end]
        self.test_dates = self.dates[val_end:]
        
        return (self.X_train, self.y_train), (self.X_val, self.y_val), (self.X_test, self.y_test)

# Xây dựng mô hình  
    def build_model(self, conv_filters=128, conv_kernel_size=3, conv_activation='relu', lstm_units=50, lstm_activation = 'relu', learning_rate=0.001):
        """Build CNN-LSTM model with given parameters"""
        model = Sequential([
            # Apply Conv1D to each sequence separately using TimeDistributed
            TimeDistributed(
                Conv1D(
                    filters=conv_filters,
                    kernel_size=conv_kernel_size,
                    activation=conv_activation
                ),
                input_shape=(self.n_seq, self.n_steps//self.n_seq, self.n_features)
            ),
            TimeDistributed(MaxPooling1D(pool_size=2)),
            TimeDistributed(Flatten()),
            LSTM(lstm_units, activation=lstm_activation),
            Dense(1)
        ])
        
        model.compile(
            optimizer=Adam(learning_rate=learning_rate),
            loss=Huber(delta=1.0),
            metrics=['mae']
        )
        return model
    
# Train để đánh giá mô hình
    def train_model(self, model, X_train, y_train, X_val, y_val, 
                    epochs=500, batch_size=32, patience=50):
        """Train model with early stopping and model checkpointing"""
        callbacks = [
            EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True),
            ModelCheckpoint('best_CNNLSTM_model.keras', monitor='val_loss', save_best_only=True)
        ]
        
        history = model.fit(
            X_train, y_train,
            validation_data=(X_val, y_val),
            epochs=epochs,
            batch_size=batch_size,
            callbacks=callbacks,
            verbose=1
        )
        return history

# Kết quả
    def forecasting_result(self, model, X, y):
        forecasting = model.predict(X)
        actual = self.scaler.inverse_transform(y.reshape(-1, 1))
        forecasting = self.scaler.inverse_transform(forecasting)
        return actual, forecasting
    
# Plot
    def plot_loss_by_epoch(self, history):
        """Plot training and validation metrics over epochs"""
        plt.figure(figsize=(14, 6))
        plt.plot(history.history['loss'], label='Train Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title('Training and Validation Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
        plt.tight_layout()
        plt.show()

    def plot_forcasting(self, dates, y_true, y_pred, title='Actual Prices vs. Predicted Prices'):
        plt.figure(figsize=(15, 6))
        plt.plot(dates, y_true, label='Actual')
        plt.plot(dates, y_pred, label='Predict')

        plt.title(title)
        plt.xlabel('Date')
        plt.ylabel('Price')
        plt.legend()
        plt.grid(True)
        plt.xticks(rotation=45)
        plt.show()

    def plot_train_validation_test_forecasting(self, model):
        """Plot predictions for all datasets"""
        # Training set
        y_train_orig, train_pred = self.forecasting_result(model, self.X_train, self.y_train)
        print("\nTraining Set Predictions:")
        self.plot_forcasting(self.train_dates, y_train_orig, train_pred, 
                            "Training Set: Actual vs Predicted")
        
        # Validation set
        y_val_orig, val_pred = self.forecasting_result(model, self.X_val, self.y_val)
        print("\nValidation Set Predictions:")
        self.plot_forcasting(self.val_dates, y_val_orig, val_pred,
                            "Validation Set: Actual vs Predicted")
        
        # Test set
        y_test_orig, test_pred = self.forecasting_result(model, self.X_test, self.y_test)
        print("\nTest Set Predictions:")
        self.plot_forcasting(self.test_dates, y_test_orig, test_pred,
                            "Test Set: Actual vs Predicted")

# Forecast
    def forecast_future(self, model, last_sequence, n_predictions=30):
        predictions = []
        current_sequence = last_sequence.copy()

        for _ in range(n_predictions):
            # Dự đoán bước tiếp theo
            pred = model.predict(
                current_sequence.reshape(1, self.n_seq, self.n_steps // self.n_seq, self.n_features),
                verbose=0
            )
            
            # Lưu trữ dự đoán mới
            predictions.append(pred[0, 0])

            # Chuẩn hóa giá trị dự đoán để đưa vào sequence
            pred_scaled = self.scaler.transform(pred)

            # Cập nhật current_sequence: dịch sang trái và thêm pred_scaled vào cuối
            current_sequence = np.roll(current_sequence, -1, axis=1)
            current_sequence[:, -1, :] = pred_scaled.reshape(-1, 1)

        # Chuyển đổi dự đoán về thang đo gốc
        predictions = self.scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
        return predictions

    
def create_forecasting_dataframe(df, model, predictor, X_train, X_val, X_test):
    train_predictions = model.predict(X_train)
    val_predictions = model.predict(X_val)
    test_predictions = model.predict(X_test)

    train_predictions = predictor.scaler.inverse_transform(train_predictions)
    val_predictions = predictor.scaler.inverse_transform(val_predictions)
    test_predictions = predictor.scaler.inverse_transform(test_predictions)
    
    train_dates = predictor.train_dates
    val_dates = predictor.val_dates
    test_dates = predictor.test_dates

    train_df = pd.DataFrame({
        'date': train_dates,
        'actual': df.loc[df['date'].isin(train_dates), 'close'].values,
        'predict_CNNLSTM': train_predictions.flatten()
    })
    val_df = pd.DataFrame({
        'date': val_dates,
        'actual': df.loc[df['date'].isin(val_dates), 'close'].values,
        'predict_CNNLSTM': val_predictions.flatten()
    })
    test_df = pd.DataFrame({
        'date': test_dates,
        'actual': df.loc[df['date'].isin(test_dates), 'close'].values,
        'predict_CNNLSTM': test_predictions.flatten()
    })
    
    historical_df = pd.concat([train_df, val_df, test_df], ignore_index=True)

    last_sequence = X_test[-1]  # Sử dụng sequence cuối cùng trong tập kiểm tra
    future_dates = pd.date_range(start='2024-10-11', end='2024-12-31', freq='B')  # 'B' là ngày làm việc
    future_predictions = predictor.forecast_future(model, last_sequence, len(future_dates))

    future_df = pd.DataFrame({
        'date': future_dates,
        'actual': np.nan,
        'predict_CNNLSTM': future_predictions.flatten()
    })

    result_df = pd.concat([historical_df, future_df], ignore_index=True)
    result_df['date'] = pd.to_datetime(result_df['date'])
    result_df = result_df.sort_values('date').reset_index(drop=True)
    
    return result_df

def CNNLSTMforecasting(df, n_steps=10, n_seq=2):
    predictor = CNNLSTMPredictor(n_steps=n_steps, n_seq=n_seq, n_features=1)
    
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = predictor.prepare_data(df)
    
    model = predictor.build_model()
    
    history = predictor.train_model(
        model, X_train, y_train, X_val, y_val
    )

    #Plot loss over epoch
    predictor.plot_loss_by_epoch(history)

    return model, predictor, history, X_train, y_train, X_val, y_val, X_test, y_test

def model_metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = root_mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    return mae, rmse, r2, mape

# %% [markdown]
# ## Experiments with different values of n_steps

# %%
def n_steps_experiments(df):
    configs = [
        {'n_steps': 5, 'n_seq': 1},
        {'n_steps': 10, 'n_seq': 2},
        {'n_steps': 15, 'n_seq': 3},
        {'n_steps': 20, 'n_seq': 4},
        {'n_steps': 30, 'n_seq': 6},
    ]
    
    results = []
    
    for config in configs:
        print(f"\nTesting configuration: n_steps={config['n_steps']} (equivalent to {config['n_steps']/5:.1f} weeks)")
        print(f"Number of sequences: {config['n_seq']} (each sequence ~{config['n_steps']/config['n_seq']/5:.1f} weeks)")

        # Train model with current configuration
        model, predictor, history, X_train, y_train, X_val, y_val, X_test, y_test = CNNLSTMforecasting(df, n_steps=config['n_steps'], n_seq=config['n_seq'])

        # Get predictions for validation set
        y_val_orig, val_pred = predictor.forecasting_result(model, X_val, y_val)
        # Calculate validation metrics
        val_mae, val_rmse, val_r2, val_mape = model_metrics(y_val_orig, val_pred)

        # Get predictions for test set
        y_test_orig, test_pred = predictor.forecasting_result(model, X_test, y_test)
        # Calculate test metrics
        mae, rmse, r2, mape = model_metrics(y_test_orig, test_pred)

        results.append({
            'n_steps': config['n_steps'],
            'weeks': config['n_steps'] / 5,
            'n_seq': config['n_seq'],
            'weeks_per_seq': config['n_steps'] / config['n_seq'] / 5,
            'Val MAE': val_mae,
            'Val RMSE': val_rmse,
            'Val R2': val_r2,
            'Val MAPE': val_mape,
            'Test MAE': mae,
            'Test RMSE': rmse,
            'Test R2': r2,
            'Test MAPE': mape
        })

        # Plot predictions for validation set
        plt.figure(figsize=(15, 6))
        plt.plot(predictor.val_dates, y_val_orig, label='Actual (Validation)')
        plt.plot(predictor.val_dates, val_pred, label='Predicted (Validation)')
        plt.title(f'Validation Set Predictions\n{config["n_steps"]} days ({config["n_steps"]/5:.1f} weeks), {config["n_seq"]} sequences')
        plt.xlabel('Date')
        plt.ylabel('Price')
        plt.legend()
        plt.grid(True)
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()

        # Plot predictions for test set
        plt.figure(figsize=(15, 6))
        plt.plot(predictor.test_dates, y_test_orig, label='Actual (Test)')
        plt.plot(predictor.test_dates, test_pred, label='Predicted (Test)')
        plt.title(f'Test Set Predictions\n{config["n_steps"]} days ({config["n_steps"]/5:.1f} weeks), {config["n_seq"]} sequences')
        plt.xlabel('Date')
        plt.ylabel('Price')
        plt.legend()
        plt.grid(True)
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()

    return results

# %%
results_n_steps_experiments = n_steps_experiments(df)
# Out:
# Testing configuration: n_steps=5 (equivalent to 1.0 weeks)
# Number of sequences: 1 (each sequence ~1.0 weeks)
# Epoch 1/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0283 - mae: 0.1522 - val_loss: 0.0022 - val_mae: 0.0583
# Epoch 2/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0967e-04 - mae: 0.0263 - val_loss: 0.0014 - val_mae: 0.0427
# Epoch 3/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0361e-04 - mae: 0.0195 - val_loss: 0.0012 - val_mae: 0.0403
# Epoch 4/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2526e-04 - mae: 0.0192 - val_loss: 0.0012 - val_mae: 0.0398
# Epoch 5/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7951e-04 - mae: 0.0183 - val_loss: 0.0011 - val_mae: 0.0371
# Epoch 6/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3820e-04 - mae: 0.0172 - val_loss: 9.9775e-04 - val_mae: 0.0358
# Epoch 7/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3718e-04 - mae: 0.0170 - val_loss: 8.5336e-04 - val_mae: 0.0320
# Epoch 8/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4229e-04 - mae: 0.0170 - val_loss: 8.8504e-04 - val_mae: 0.0331
# Epoch 9/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7855e-04 - mae: 0.0185 - val_loss: 8.3329e-04 - val_mae: 0.0317
# Epoch 10/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1415e-04 - mae: 0.0164 - val_loss: 9.7949e-04 - val_mae: 0.0356
# Epoch 11/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4853e-04 - mae: 0.0173 - val_loss: 8.0413e-04 - val_mae: 0.0310
# Epoch 12/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9702e-04 - mae: 0.0163 - val_loss: 9.8835e-04 - val_mae: 0.0359
# Epoch 13/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4351e-04 - mae: 0.0172 - val_loss: 7.7321e-04 - val_mae: 0.0298
# Epoch 14/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0025e-04 - mae: 0.0161 - val_loss: 8.3096e-04 - val_mae: 0.0321
# Epoch 15/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0520e-04 - mae: 0.0161 - val_loss: 7.4095e-04 - val_mae: 0.0294
# Epoch 16/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3707e-04 - mae: 0.0170 - val_loss: 7.5022e-04 - val_mae: 0.0295
# Epoch 17/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3551e-04 - mae: 0.0166 - val_loss: 7.3298e-04 - val_mae: 0.0288
# Epoch 18/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4364e-04 - mae: 0.0170 - val_loss: 7.6307e-04 - val_mae: 0.0304
# Epoch 19/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8488e-04 - mae: 0.0156 - val_loss: 7.2181e-04 - val_mae: 0.0289
# Epoch 20/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1882e-04 - mae: 0.0161 - val_loss: 8.1113e-04 - val_mae: 0.0316
# Epoch 21/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5858e-04 - mae: 0.0175 - val_loss: 6.9887e-04 - val_mae: 0.0283
# Epoch 22/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2292e-04 - mae: 0.0159 - val_loss: 6.8187e-04 - val_mae: 0.0272
# Epoch 23/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1504e-04 - mae: 0.0172 - val_loss: 7.3352e-04 - val_mae: 0.0294
# Epoch 24/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9110e-04 - mae: 0.0158 - val_loss: 6.6430e-04 - val_mae: 0.0273
# Epoch 25/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2926e-04 - mae: 0.0162 - val_loss: 9.8170e-04 - val_mae: 0.0361
# Epoch 26/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1380e-04 - mae: 0.0173 - val_loss: 6.6961e-04 - val_mae: 0.0276
# Epoch 27/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9797e-04 - mae: 0.0159 - val_loss: 6.9569e-04 - val_mae: 0.0285
# Epoch 28/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3089e-04 - mae: 0.0166 - val_loss: 6.8061e-04 - val_mae: 0.0270
# Epoch 29/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9853e-04 - mae: 0.0164 - val_loss: 9.9286e-04 - val_mae: 0.0366
# Epoch 30/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9720e-04 - mae: 0.0158 - val_loss: 6.4966e-04 - val_mae: 0.0271
# Epoch 31/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8318e-04 - mae: 0.0157 - val_loss: 6.5668e-04 - val_mae: 0.0273
# Epoch 32/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1532e-04 - mae: 0.0164 - val_loss: 6.8976e-04 - val_mae: 0.0270
# Epoch 33/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8805e-04 - mae: 0.0155 - val_loss: 7.8696e-04 - val_mae: 0.0316
# Epoch 34/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8043e-04 - mae: 0.0159 - val_loss: 7.5860e-04 - val_mae: 0.0309
# Epoch 35/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0776e-04 - mae: 0.0161 - val_loss: 6.8706e-04 - val_mae: 0.0287
# Epoch 36/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6781e-04 - mae: 0.0150 - val_loss: 6.6388e-04 - val_mae: 0.0280
# Epoch 37/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2299e-04 - mae: 0.0164 - val_loss: 6.2776e-04 - val_mae: 0.0264
# Epoch 38/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7223e-04 - mae: 0.0161 - val_loss: 6.3714e-04 - val_mae: 0.0270
# Epoch 39/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7943e-04 - mae: 0.0154 - val_loss: 6.4008e-04 - val_mae: 0.0270
# Epoch 40/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8008e-04 - mae: 0.0152 - val_loss: 6.1787e-04 - val_mae: 0.0264
# Epoch 41/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9295e-04 - mae: 0.0154 - val_loss: 6.8576e-04 - val_mae: 0.0288
# Epoch 42/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0337e-04 - mae: 0.0154 - val_loss: 6.4932e-04 - val_mae: 0.0276
# Epoch 43/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9083e-04 - mae: 0.0154 - val_loss: 6.1606e-04 - val_mae: 0.0263
# Epoch 44/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9773e-04 - mae: 0.0157 - val_loss: 6.9922e-04 - val_mae: 0.0293
# Epoch 45/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7982e-04 - mae: 0.0154 - val_loss: 6.1755e-04 - val_mae: 0.0265
# Epoch 46/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.7874e-04 - mae: 0.0155 - val_loss: 6.3694e-04 - val_mae: 0.0264
# Epoch 47/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0078e-04 - mae: 0.0156 - val_loss: 6.0361e-04 - val_mae: 0.0259
# Epoch 48/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8862e-04 - mae: 0.0153 - val_loss: 6.1866e-04 - val_mae: 0.0264
# Epoch 49/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7925e-04 - mae: 0.0152 - val_loss: 6.2501e-04 - val_mae: 0.0269
# Epoch 50/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6544e-04 - mae: 0.0150 - val_loss: 6.2655e-04 - val_mae: 0.0269
# Epoch 51/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9610e-04 - mae: 0.0156 - val_loss: 6.6197e-04 - val_mae: 0.0282
# Epoch 52/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3581e-04 - mae: 0.0161 - val_loss: 6.7575e-04 - val_mae: 0.0272
# Epoch 53/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9335e-04 - mae: 0.0153 - val_loss: 6.0112e-04 - val_mae: 0.0256
# Epoch 54/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5630e-04 - mae: 0.0148 - val_loss: 6.3606e-04 - val_mae: 0.0263
# Epoch 55/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1790e-04 - mae: 0.0156 - val_loss: 7.8721e-04 - val_mae: 0.0318
# Epoch 56/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1470e-04 - mae: 0.0164 - val_loss: 6.6136e-04 - val_mae: 0.0281
# Epoch 57/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5823e-04 - mae: 0.0149 - val_loss: 6.3924e-04 - val_mae: 0.0263
# Epoch 58/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2985e-04 - mae: 0.0161 - val_loss: 6.1233e-04 - val_mae: 0.0259
# Epoch 59/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8948e-04 - mae: 0.0155 - val_loss: 6.6531e-04 - val_mae: 0.0282
# Epoch 60/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9633e-04 - mae: 0.0158 - val_loss: 7.0191e-04 - val_mae: 0.0276
# Epoch 61/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0165e-04 - mae: 0.0158 - val_loss: 6.6423e-04 - val_mae: 0.0269
# Epoch 62/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9222e-04 - mae: 0.0154 - val_loss: 6.0195e-04 - val_mae: 0.0258
# Epoch 63/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7116e-04 - mae: 0.0148 - val_loss: 6.9494e-04 - val_mae: 0.0291
# Epoch 64/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8882e-04 - mae: 0.0150 - val_loss: 5.9346e-04 - val_mae: 0.0258
# Epoch 65/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6409e-04 - mae: 0.0147 - val_loss: 5.9894e-04 - val_mae: 0.0260
# Epoch 66/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7917e-04 - mae: 0.0148 - val_loss: 6.7359e-04 - val_mae: 0.0286
# Epoch 67/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8902e-04 - mae: 0.0155 - val_loss: 6.2546e-04 - val_mae: 0.0269
# Epoch 68/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9750e-04 - mae: 0.0155 - val_loss: 8.2216e-04 - val_mae: 0.0305
# Epoch 69/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2038e-04 - mae: 0.0165 - val_loss: 6.1428e-04 - val_mae: 0.0258
# Epoch 70/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8062e-04 - mae: 0.0155 - val_loss: 9.8728e-04 - val_mae: 0.0338
# Epoch 71/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0615e-04 - mae: 0.0160 - val_loss: 5.9274e-04 - val_mae: 0.0256
# Epoch 72/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6429e-04 - mae: 0.0147 - val_loss: 5.9985e-04 - val_mae: 0.0256
# Epoch 73/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6170e-04 - mae: 0.0144 - val_loss: 6.0386e-04 - val_mae: 0.0257
# Epoch 74/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5160e-04 - mae: 0.0150 - val_loss: 6.6222e-04 - val_mae: 0.0269
# Epoch 75/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2649e-04 - mae: 0.0163 - val_loss: 5.9856e-04 - val_mae: 0.0260
# Epoch 76/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6194e-04 - mae: 0.0149 - val_loss: 6.2963e-04 - val_mae: 0.0261
# Epoch 77/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8348e-04 - mae: 0.0150 - val_loss: 7.1694e-04 - val_mae: 0.0297
# Epoch 78/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0420e-04 - mae: 0.0162 - val_loss: 6.1789e-04 - val_mae: 0.0259
# Epoch 79/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7750e-04 - mae: 0.0156 - val_loss: 5.9612e-04 - val_mae: 0.0258
# Epoch 80/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9451e-04 - mae: 0.0158 - val_loss: 7.4712e-04 - val_mae: 0.0288
# Epoch 81/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1070e-04 - mae: 0.0164 - val_loss: 6.0078e-04 - val_mae: 0.0262
# Epoch 82/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6228e-04 - mae: 0.0147 - val_loss: 5.9641e-04 - val_mae: 0.0256
# Epoch 83/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9411e-04 - mae: 0.0153 - val_loss: 6.3514e-04 - val_mae: 0.0274
# Epoch 84/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6655e-04 - mae: 0.0150 - val_loss: 6.8396e-04 - val_mae: 0.0287
# Epoch 85/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7593e-04 - mae: 0.0157 - val_loss: 6.0735e-04 - val_mae: 0.0257
# Epoch 86/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8967e-04 - mae: 0.0151 - val_loss: 6.1280e-04 - val_mae: 0.0266
# Epoch 87/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7178e-04 - mae: 0.0154 - val_loss: 6.0965e-04 - val_mae: 0.0258
# Epoch 88/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9744e-04 - mae: 0.0152 - val_loss: 6.4727e-04 - val_mae: 0.0265
# Epoch 89/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9191e-04 - mae: 0.0148 - val_loss: 6.1872e-04 - val_mae: 0.0269
# Epoch 90/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1765e-04 - mae: 0.0154 - val_loss: 6.5026e-04 - val_mae: 0.0278
# Epoch 91/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5497e-04 - mae: 0.0144 - val_loss: 6.1228e-04 - val_mae: 0.0267
# Epoch 92/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6085e-04 - mae: 0.0147 - val_loss: 6.2825e-04 - val_mae: 0.0272
# Epoch 93/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4767e-04 - mae: 0.0151 - val_loss: 6.7217e-04 - val_mae: 0.0286
# Epoch 94/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3654e-04 - mae: 0.0142 - val_loss: 5.9368e-04 - val_mae: 0.0256
# Epoch 95/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7327e-04 - mae: 0.0148 - val_loss: 6.1860e-04 - val_mae: 0.0259
# Epoch 96/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8368e-04 - mae: 0.0154 - val_loss: 5.9389e-04 - val_mae: 0.0260
# Epoch 97/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9643e-04 - mae: 0.0155 - val_loss: 5.9489e-04 - val_mae: 0.0255
# Epoch 98/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4124e-04 - mae: 0.0142 - val_loss: 6.0341e-04 - val_mae: 0.0264
# Epoch 99/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5464e-04 - mae: 0.0150 - val_loss: 7.0610e-04 - val_mae: 0.0278
# Epoch 100/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5021e-04 - mae: 0.0146 - val_loss: 5.8502e-04 - val_mae: 0.0254
# Epoch 101/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6016e-04 - mae: 0.0150 - val_loss: 5.9064e-04 - val_mae: 0.0257
# Epoch 102/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7358e-04 - mae: 0.0148 - val_loss: 5.9017e-04 - val_mae: 0.0255
# Epoch 103/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2284e-04 - mae: 0.0165 - val_loss: 6.0793e-04 - val_mae: 0.0259
# Epoch 104/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9335e-04 - mae: 0.0152 - val_loss: 5.9450e-04 - val_mae: 0.0254
# Epoch 105/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2647e-04 - mae: 0.0162 - val_loss: 6.1225e-04 - val_mae: 0.0266
# Epoch 106/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9900e-04 - mae: 0.0156 - val_loss: 0.0013 - val_mae: 0.0428
# Epoch 107/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8953e-04 - mae: 0.0187 - val_loss: 5.9292e-04 - val_mae: 0.0258
# Epoch 108/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6790e-04 - mae: 0.0148 - val_loss: 7.6599e-04 - val_mae: 0.0311
# Epoch 109/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0223e-04 - mae: 0.0159 - val_loss: 6.0775e-04 - val_mae: 0.0264
# Epoch 110/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5976e-04 - mae: 0.0147 - val_loss: 6.5075e-04 - val_mae: 0.0278
# Epoch 111/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8271e-04 - mae: 0.0155 - val_loss: 5.9811e-04 - val_mae: 0.0255
# Epoch 112/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3817e-04 - mae: 0.0141 - val_loss: 5.9161e-04 - val_mae: 0.0256
# Epoch 113/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8155e-04 - mae: 0.0149 - val_loss: 6.7834e-04 - val_mae: 0.0287
# Epoch 114/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8169e-04 - mae: 0.0152 - val_loss: 6.0174e-04 - val_mae: 0.0258
# Epoch 115/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6927e-04 - mae: 0.0148 - val_loss: 6.1118e-04 - val_mae: 0.0258
# Epoch 116/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6833e-04 - mae: 0.0148 - val_loss: 6.5258e-04 - val_mae: 0.0280
# Epoch 117/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3541e-04 - mae: 0.0170 - val_loss: 6.1922e-04 - val_mae: 0.0268
# Epoch 118/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5778e-04 - mae: 0.0146 - val_loss: 6.6615e-04 - val_mae: 0.0283
# Epoch 119/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8662e-04 - mae: 0.0151 - val_loss: 6.3202e-04 - val_mae: 0.0272
# Epoch 120/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7304e-04 - mae: 0.0148 - val_loss: 6.7306e-04 - val_mae: 0.0286
# Epoch 121/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2798e-04 - mae: 0.0158 - val_loss: 6.0280e-04 - val_mae: 0.0263
# Epoch 122/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8396e-04 - mae: 0.0147 - val_loss: 5.9526e-04 - val_mae: 0.0259
# Epoch 123/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2740e-04 - mae: 0.0157 - val_loss: 6.3387e-04 - val_mae: 0.0274
# Epoch 124/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6439e-04 - mae: 0.0151 - val_loss: 6.0470e-04 - val_mae: 0.0264
# Epoch 125/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9247e-04 - mae: 0.0152 - val_loss: 5.8813e-04 - val_mae: 0.0258
# Epoch 126/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8027e-04 - mae: 0.0152 - val_loss: 6.2639e-04 - val_mae: 0.0261
# Epoch 127/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7990e-04 - mae: 0.0151 - val_loss: 5.9951e-04 - val_mae: 0.0262
# Epoch 128/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8670e-04 - mae: 0.0150 - val_loss: 7.8715e-04 - val_mae: 0.0317
# Epoch 129/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7752e-04 - mae: 0.0150 - val_loss: 6.0542e-04 - val_mae: 0.0265
# Epoch 130/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5085e-04 - mae: 0.0141 - val_loss: 8.2649e-04 - val_mae: 0.0328
# Epoch 131/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6183e-04 - mae: 0.0147 - val_loss: 6.0810e-04 - val_mae: 0.0257
# Epoch 132/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5476e-04 - mae: 0.0149 - val_loss: 6.1852e-04 - val_mae: 0.0268
# Epoch 133/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7417e-04 - mae: 0.0152 - val_loss: 5.8588e-04 - val_mae: 0.0253
# Epoch 134/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2210e-04 - mae: 0.0140 - val_loss: 6.1792e-04 - val_mae: 0.0269
# Epoch 135/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4646e-04 - mae: 0.0144 - val_loss: 6.3770e-04 - val_mae: 0.0276
# Epoch 136/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5824e-04 - mae: 0.0151 - val_loss: 6.0554e-04 - val_mae: 0.0260
# Epoch 137/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2466e-04 - mae: 0.0166 - val_loss: 6.0158e-04 - val_mae: 0.0257
# Epoch 138/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4411e-04 - mae: 0.0144 - val_loss: 6.7602e-04 - val_mae: 0.0271
# Epoch 139/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9114e-04 - mae: 0.0154 - val_loss: 6.8365e-04 - val_mae: 0.0274
# Epoch 140/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6294e-04 - mae: 0.0150 - val_loss: 7.4962e-04 - val_mae: 0.0307
# Epoch 141/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9810e-04 - mae: 0.0153 - val_loss: 6.1910e-04 - val_mae: 0.0260
# Epoch 142/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8538e-04 - mae: 0.0159 - val_loss: 6.6862e-04 - val_mae: 0.0284
# Epoch 143/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5827e-04 - mae: 0.0151 - val_loss: 6.0180e-04 - val_mae: 0.0262
# Epoch 144/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7175e-04 - mae: 0.0156 - val_loss: 6.3559e-04 - val_mae: 0.0263
# Epoch 145/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7922e-04 - mae: 0.0147 - val_loss: 6.1410e-04 - val_mae: 0.0259
# Epoch 146/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3666e-04 - mae: 0.0144 - val_loss: 6.5341e-04 - val_mae: 0.0281
# Epoch 147/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7666e-04 - mae: 0.0148 - val_loss: 5.9258e-04 - val_mae: 0.0258
# Epoch 148/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7309e-04 - mae: 0.0146 - val_loss: 6.0399e-04 - val_mae: 0.0264
# Epoch 149/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1991e-04 - mae: 0.0156 - val_loss: 6.3297e-04 - val_mae: 0.0274
# Epoch 150/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9989e-04 - mae: 0.0155 - val_loss: 7.2467e-04 - val_mae: 0.0302
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Testing configuration: n_steps=10 (equivalent to 2.0 weeks)
# Number of sequences: 2 (each sequence ~1.0 weeks)
# Epoch 1/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0209 - mae: 0.1255 - val_loss: 0.0016 - val_mae: 0.0455
# Epoch 2/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9440e-04 - mae: 0.0224 - val_loss: 0.0014 - val_mae: 0.0424
# Epoch 3/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6896e-04 - mae: 0.0202 - val_loss: 0.0013 - val_mae: 0.0418
# Epoch 4/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3953e-04 - mae: 0.0198 - val_loss: 0.0013 - val_mae: 0.0406
# Epoch 5/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3061e-04 - mae: 0.0196 - val_loss: 0.0010 - val_mae: 0.0332
# Epoch 6/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0916e-04 - mae: 0.0194 - val_loss: 9.5639e-04 - val_mae: 0.0324
# Epoch 7/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6769e-04 - mae: 0.0207 - val_loss: 9.8320e-04 - val_mae: 0.0346
# Epoch 8/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7867e-04 - mae: 0.0184 - val_loss: 0.0016 - val_mae: 0.0474
# Epoch 9/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4194e-04 - mae: 0.0198 - val_loss: 8.9887e-04 - val_mae: 0.0328
# Epoch 10/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7295e-04 - mae: 0.0178 - val_loss: 8.4851e-04 - val_mae: 0.0316
# Epoch 11/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4425e-04 - mae: 0.0179 - val_loss: 7.9693e-04 - val_mae: 0.0293
# Epoch 12/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9434e-04 - mae: 0.0176 - val_loss: 8.0866e-04 - val_mae: 0.0313
# Epoch 13/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4435e-04 - mae: 0.0173 - val_loss: 7.4947e-04 - val_mae: 0.0294
# Epoch 14/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5084e-04 - mae: 0.0167 - val_loss: 7.6926e-04 - val_mae: 0.0285
# Epoch 15/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1307e-04 - mae: 0.0164 - val_loss: 8.9155e-04 - val_mae: 0.0340
# Epoch 16/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1808e-04 - mae: 0.0167 - val_loss: 9.7187e-04 - val_mae: 0.0360
# Epoch 17/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.3944e-04 - mae: 0.0165 - val_loss: 7.9388e-04 - val_mae: 0.0315
# Epoch 18/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3514e-04 - mae: 0.0167 - val_loss: 6.5543e-04 - val_mae: 0.0272
# Epoch 19/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2134e-04 - mae: 0.0163 - val_loss: 7.1580e-04 - val_mae: 0.0294
# Epoch 20/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8073e-04 - mae: 0.0156 - val_loss: 6.8546e-04 - val_mae: 0.0284
# Epoch 21/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8251e-04 - mae: 0.0158 - val_loss: 7.4761e-04 - val_mae: 0.0283
# Epoch 22/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1995e-04 - mae: 0.0166 - val_loss: 8.7843e-04 - val_mae: 0.0338
# Epoch 23/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8762e-04 - mae: 0.0158 - val_loss: 6.7563e-04 - val_mae: 0.0272
# Epoch 24/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7347e-04 - mae: 0.0154 - val_loss: 6.4111e-04 - val_mae: 0.0266
# Epoch 25/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9835e-04 - mae: 0.0156 - val_loss: 6.9583e-04 - val_mae: 0.0289
# Epoch 26/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2783e-04 - mae: 0.0162 - val_loss: 6.3943e-04 - val_mae: 0.0269
# Epoch 27/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9658e-04 - mae: 0.0159 - val_loss: 7.3750e-04 - val_mae: 0.0302
# Epoch 28/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6772e-04 - mae: 0.0159 - val_loss: 7.7531e-04 - val_mae: 0.0312
# Epoch 29/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4257e-04 - mae: 0.0163 - val_loss: 6.9484e-04 - val_mae: 0.0289
# Epoch 30/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9664e-04 - mae: 0.0159 - val_loss: 6.3693e-04 - val_mae: 0.0265
# Epoch 31/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4622e-04 - mae: 0.0148 - val_loss: 0.0014 - val_mae: 0.0448
# Epoch 32/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6298e-04 - mae: 0.0179 - val_loss: 6.6410e-04 - val_mae: 0.0267
# Epoch 33/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0404e-04 - mae: 0.0159 - val_loss: 6.4058e-04 - val_mae: 0.0264
# Epoch 34/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7919e-04 - mae: 0.0156 - val_loss: 6.7481e-04 - val_mae: 0.0282
# Epoch 35/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2233e-04 - mae: 0.0167 - val_loss: 6.4407e-04 - val_mae: 0.0269
# Epoch 36/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8466e-04 - mae: 0.0160 - val_loss: 6.2856e-04 - val_mae: 0.0265
# Epoch 37/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5280e-04 - mae: 0.0151 - val_loss: 6.4016e-04 - val_mae: 0.0272
# Epoch 38/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8634e-04 - mae: 0.0160 - val_loss: 6.7634e-04 - val_mae: 0.0283
# Epoch 39/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6127e-04 - mae: 0.0147 - val_loss: 6.2942e-04 - val_mae: 0.0264
# Epoch 40/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7297e-04 - mae: 0.0153 - val_loss: 6.3069e-04 - val_mae: 0.0267
# Epoch 41/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8423e-04 - mae: 0.0156 - val_loss: 6.6581e-04 - val_mae: 0.0267
# Epoch 42/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8738e-04 - mae: 0.0159 - val_loss: 6.3404e-04 - val_mae: 0.0268
# Epoch 43/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9095e-04 - mae: 0.0156 - val_loss: 6.4511e-04 - val_mae: 0.0273
# Epoch 44/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4672e-04 - mae: 0.0162 - val_loss: 8.2278e-04 - val_mae: 0.0299
# Epoch 45/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8466e-04 - mae: 0.0153 - val_loss: 7.0252e-04 - val_mae: 0.0293
# Epoch 46/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8714e-04 - mae: 0.0154 - val_loss: 6.6980e-04 - val_mae: 0.0282
# Epoch 47/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8648e-04 - mae: 0.0156 - val_loss: 7.0734e-04 - val_mae: 0.0275
# Epoch 48/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8528e-04 - mae: 0.0168 - val_loss: 6.9675e-04 - val_mae: 0.0291
# Epoch 49/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1360e-04 - mae: 0.0159 - val_loss: 6.4306e-04 - val_mae: 0.0263
# Epoch 50/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9593e-04 - mae: 0.0160 - val_loss: 7.3177e-04 - val_mae: 0.0302
# Epoch 51/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8310e-04 - mae: 0.0155 - val_loss: 7.5722e-04 - val_mae: 0.0309
# Epoch 52/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5139e-04 - mae: 0.0149 - val_loss: 6.1898e-04 - val_mae: 0.0262
# Epoch 53/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6123e-04 - mae: 0.0149 - val_loss: 6.6118e-04 - val_mae: 0.0266
# Epoch 54/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2010e-04 - mae: 0.0156 - val_loss: 7.1394e-04 - val_mae: 0.0297
# Epoch 55/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7580e-04 - mae: 0.0149 - val_loss: 6.4878e-04 - val_mae: 0.0264
# Epoch 56/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0560e-04 - mae: 0.0161 - val_loss: 6.2348e-04 - val_mae: 0.0261
# Epoch 57/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5468e-04 - mae: 0.0149 - val_loss: 6.2595e-04 - val_mae: 0.0267
# Epoch 58/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8618e-04 - mae: 0.0152 - val_loss: 7.1988e-04 - val_mae: 0.0298
# Epoch 59/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4560e-04 - mae: 0.0150 - val_loss: 6.4658e-04 - val_mae: 0.0276
# Epoch 60/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9964e-04 - mae: 0.0158 - val_loss: 6.5658e-04 - val_mae: 0.0266
# Epoch 61/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3965e-04 - mae: 0.0150 - val_loss: 6.1019e-04 - val_mae: 0.0261
# Epoch 62/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8785e-04 - mae: 0.0156 - val_loss: 7.4746e-04 - val_mae: 0.0284
# Epoch 63/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9974e-04 - mae: 0.0156 - val_loss: 6.7066e-04 - val_mae: 0.0284
# Epoch 64/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5634e-04 - mae: 0.0147 - val_loss: 6.8353e-04 - val_mae: 0.0288
# Epoch 65/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7165e-04 - mae: 0.0153 - val_loss: 8.9741e-04 - val_mae: 0.0346
# Epoch 66/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3503e-04 - mae: 0.0164 - val_loss: 6.2463e-04 - val_mae: 0.0265
# Epoch 67/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3374e-04 - mae: 0.0144 - val_loss: 7.9872e-04 - val_mae: 0.0296
# Epoch 68/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9633e-04 - mae: 0.0158 - val_loss: 7.1749e-04 - val_mae: 0.0277
# Epoch 69/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7837e-04 - mae: 0.0149 - val_loss: 9.5380e-04 - val_mae: 0.0359
# Epoch 70/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0469e-04 - mae: 0.0157 - val_loss: 8.8026e-04 - val_mae: 0.0312
# Epoch 71/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2081e-04 - mae: 0.0154 - val_loss: 6.2889e-04 - val_mae: 0.0266
# Epoch 72/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1006e-04 - mae: 0.0152 - val_loss: 6.3402e-04 - val_mae: 0.0271
# Epoch 73/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5006e-04 - mae: 0.0144 - val_loss: 6.9278e-04 - val_mae: 0.0272
# Epoch 74/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2255e-04 - mae: 0.0169 - val_loss: 6.4172e-04 - val_mae: 0.0265
# Epoch 75/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5562e-04 - mae: 0.0147 - val_loss: 6.0980e-04 - val_mae: 0.0259
# Epoch 76/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6929e-04 - mae: 0.0149 - val_loss: 6.2054e-04 - val_mae: 0.0259
# Epoch 77/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8897e-04 - mae: 0.0154 - val_loss: 6.2355e-04 - val_mae: 0.0268
# Epoch 78/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8313e-04 - mae: 0.0152 - val_loss: 6.3053e-04 - val_mae: 0.0261
# Epoch 79/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9160e-04 - mae: 0.0152 - val_loss: 7.0853e-04 - val_mae: 0.0277
# Epoch 80/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6965e-04 - mae: 0.0157 - val_loss: 6.1422e-04 - val_mae: 0.0260
# Epoch 81/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6872e-04 - mae: 0.0149 - val_loss: 6.4724e-04 - val_mae: 0.0277
# Epoch 82/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5723e-04 - mae: 0.0150 - val_loss: 8.9700e-04 - val_mae: 0.0346
# Epoch 83/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1424e-04 - mae: 0.0167 - val_loss: 6.5794e-04 - val_mae: 0.0265
# Epoch 84/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4481e-04 - mae: 0.0170 - val_loss: 6.0755e-04 - val_mae: 0.0260
# Epoch 85/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5441e-04 - mae: 0.0146 - val_loss: 6.4580e-04 - val_mae: 0.0277
# Epoch 86/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0067e-04 - mae: 0.0151 - val_loss: 7.8885e-04 - val_mae: 0.0318
# Epoch 87/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8263e-04 - mae: 0.0153 - val_loss: 6.6688e-04 - val_mae: 0.0268
# Epoch 88/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3028e-04 - mae: 0.0164 - val_loss: 6.2045e-04 - val_mae: 0.0268
# Epoch 89/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7269e-04 - mae: 0.0149 - val_loss: 6.2329e-04 - val_mae: 0.0259
# Epoch 90/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5416e-04 - mae: 0.0151 - val_loss: 5.9625e-04 - val_mae: 0.0256
# Epoch 91/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5413e-04 - mae: 0.0145 - val_loss: 6.1791e-04 - val_mae: 0.0260
# Epoch 92/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9731e-04 - mae: 0.0152 - val_loss: 6.4848e-04 - val_mae: 0.0278
# Epoch 93/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5994e-04 - mae: 0.0149 - val_loss: 6.4539e-04 - val_mae: 0.0264
# Epoch 94/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7841e-04 - mae: 0.0148 - val_loss: 6.4318e-04 - val_mae: 0.0276
# Epoch 95/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4246e-04 - mae: 0.0162 - val_loss: 6.0580e-04 - val_mae: 0.0257
# Epoch 96/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1932e-04 - mae: 0.0157 - val_loss: 6.6566e-04 - val_mae: 0.0283
# Epoch 97/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6650e-04 - mae: 0.0153 - val_loss: 5.9765e-04 - val_mae: 0.0256
# Epoch 98/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0604e-04 - mae: 0.0154 - val_loss: 6.0498e-04 - val_mae: 0.0261
# Epoch 99/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6724e-04 - mae: 0.0146 - val_loss: 6.4442e-04 - val_mae: 0.0276
# Epoch 100/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7871e-04 - mae: 0.0154 - val_loss: 7.3741e-04 - val_mae: 0.0304
# Epoch 101/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0800e-04 - mae: 0.0156 - val_loss: 6.2167e-04 - val_mae: 0.0260
# Epoch 102/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3583e-04 - mae: 0.0144 - val_loss: 6.6053e-04 - val_mae: 0.0267
# Epoch 103/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8213e-04 - mae: 0.0154 - val_loss: 8.9819e-04 - val_mae: 0.0319
# Epoch 104/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6569e-04 - mae: 0.0153 - val_loss: 6.5658e-04 - val_mae: 0.0267
# Epoch 105/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0338e-04 - mae: 0.0151 - val_loss: 0.0010 - val_mae: 0.0372
# Epoch 106/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0738e-04 - mae: 0.0156 - val_loss: 6.1360e-04 - val_mae: 0.0266
# Epoch 107/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5288e-04 - mae: 0.0145 - val_loss: 6.3327e-04 - val_mae: 0.0274
# Epoch 108/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2536e-04 - mae: 0.0160 - val_loss: 6.0958e-04 - val_mae: 0.0265
# Epoch 109/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0223e-04 - mae: 0.0151 - val_loss: 5.9569e-04 - val_mae: 0.0256
# Epoch 110/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3019e-04 - mae: 0.0143 - val_loss: 6.1189e-04 - val_mae: 0.0266
# Epoch 111/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6532e-04 - mae: 0.0149 - val_loss: 7.0118e-04 - val_mae: 0.0275
# Epoch 112/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2073e-04 - mae: 0.0138 - val_loss: 6.0861e-04 - val_mae: 0.0264
# Epoch 113/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8018e-04 - mae: 0.0150 - val_loss: 9.3926e-04 - val_mae: 0.0357
# Epoch 114/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1520e-04 - mae: 0.0160 - val_loss: 6.1464e-04 - val_mae: 0.0261
# Epoch 115/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9071e-04 - mae: 0.0153 - val_loss: 5.9696e-04 - val_mae: 0.0258
# Epoch 116/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9941e-04 - mae: 0.0151 - val_loss: 6.1719e-04 - val_mae: 0.0267
# Epoch 117/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4919e-04 - mae: 0.0145 - val_loss: 8.5975e-04 - val_mae: 0.0337
# Epoch 118/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7931e-04 - mae: 0.0160 - val_loss: 6.0600e-04 - val_mae: 0.0259
# Epoch 119/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8003e-04 - mae: 0.0149 - val_loss: 5.8369e-04 - val_mae: 0.0254
# Epoch 120/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8127e-04 - mae: 0.0154 - val_loss: 6.1704e-04 - val_mae: 0.0259
# Epoch 121/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6548e-04 - mae: 0.0147 - val_loss: 5.9442e-04 - val_mae: 0.0255
# Epoch 122/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3132e-04 - mae: 0.0164 - val_loss: 6.5063e-04 - val_mae: 0.0278
# Epoch 123/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5325e-04 - mae: 0.0148 - val_loss: 8.1933e-04 - val_mae: 0.0326
# Epoch 124/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5605e-04 - mae: 0.0151 - val_loss: 6.2697e-04 - val_mae: 0.0271
# Epoch 125/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5766e-04 - mae: 0.0141 - val_loss: 6.8000e-04 - val_mae: 0.0289
# Epoch 126/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7709e-04 - mae: 0.0151 - val_loss: 7.5893e-04 - val_mae: 0.0311
# Epoch 127/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8247e-04 - mae: 0.0152 - val_loss: 6.0475e-04 - val_mae: 0.0264
# Epoch 128/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4959e-04 - mae: 0.0145 - val_loss: 6.1147e-04 - val_mae: 0.0265
# Epoch 129/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3358e-04 - mae: 0.0163 - val_loss: 6.7283e-04 - val_mae: 0.0285
# Epoch 130/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3273e-04 - mae: 0.0136 - val_loss: 6.0364e-04 - val_mae: 0.0263
# Epoch 131/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8495e-04 - mae: 0.0152 - val_loss: 6.9225e-04 - val_mae: 0.0274
# Epoch 132/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2771e-04 - mae: 0.0159 - val_loss: 7.2435e-04 - val_mae: 0.0301
# Epoch 133/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3777e-04 - mae: 0.0143 - val_loss: 5.9252e-04 - val_mae: 0.0259
# Epoch 134/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5107e-04 - mae: 0.0149 - val_loss: 7.6551e-04 - val_mae: 0.0312
# Epoch 135/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7028e-04 - mae: 0.0153 - val_loss: 0.0013 - val_mae: 0.0434
# Epoch 136/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0283e-04 - mae: 0.0165 - val_loss: 5.9435e-04 - val_mae: 0.0256
# Epoch 137/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8107e-04 - mae: 0.0149 - val_loss: 6.1085e-04 - val_mae: 0.0259
# Epoch 138/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5046e-04 - mae: 0.0144 - val_loss: 5.9277e-04 - val_mae: 0.0260
# Epoch 139/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3031e-04 - mae: 0.0140 - val_loss: 7.0900e-04 - val_mae: 0.0295
# Epoch 140/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7301e-04 - mae: 0.0153 - val_loss: 5.9230e-04 - val_mae: 0.0257
# Epoch 141/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5218e-04 - mae: 0.0149 - val_loss: 6.0884e-04 - val_mae: 0.0266
# Epoch 142/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0023e-04 - mae: 0.0148 - val_loss: 6.0469e-04 - val_mae: 0.0257
# Epoch 143/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5813e-04 - mae: 0.0149 - val_loss: 5.9254e-04 - val_mae: 0.0258
# Epoch 144/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8073e-04 - mae: 0.0152 - val_loss: 6.5211e-04 - val_mae: 0.0266
# Epoch 145/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0294e-04 - mae: 0.0154 - val_loss: 6.3382e-04 - val_mae: 0.0262
# Epoch 146/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7468e-04 - mae: 0.0148 - val_loss: 6.4957e-04 - val_mae: 0.0281
# Epoch 147/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2624e-04 - mae: 0.0159 - val_loss: 5.8869e-04 - val_mae: 0.0255
# Epoch 148/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9903e-04 - mae: 0.0161 - val_loss: 5.9840e-04 - val_mae: 0.0261
# Epoch 149/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8280e-04 - mae: 0.0148 - val_loss: 5.8873e-04 - val_mae: 0.0254
# Epoch 150/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2123e-04 - mae: 0.0160 - val_loss: 6.3016e-04 - val_mae: 0.0263
# Epoch 151/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6681e-04 - mae: 0.0145 - val_loss: 9.3972e-04 - val_mae: 0.0358
# Epoch 152/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5084e-04 - mae: 0.0147 - val_loss: 5.9351e-04 - val_mae: 0.0258
# Epoch 153/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6057e-04 - mae: 0.0150 - val_loss: 5.8182e-04 - val_mae: 0.0255
# Epoch 154/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2948e-04 - mae: 0.0142 - val_loss: 8.4090e-04 - val_mae: 0.0332
# Epoch 155/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8028e-04 - mae: 0.0152 - val_loss: 5.8049e-04 - val_mae: 0.0255
# Epoch 156/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4934e-04 - mae: 0.0145 - val_loss: 5.9485e-04 - val_mae: 0.0257
# Epoch 157/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1446e-04 - mae: 0.0161 - val_loss: 6.1544e-04 - val_mae: 0.0260
# Epoch 158/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6673e-04 - mae: 0.0149 - val_loss: 6.0779e-04 - val_mae: 0.0258
# Epoch 159/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8149e-04 - mae: 0.0146 - val_loss: 5.8812e-04 - val_mae: 0.0255
# Epoch 160/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4679e-04 - mae: 0.0144 - val_loss: 8.2285e-04 - val_mae: 0.0329
# Epoch 161/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7640e-04 - mae: 0.0153 - val_loss: 6.0723e-04 - val_mae: 0.0266
# Epoch 162/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4373e-04 - mae: 0.0145 - val_loss: 5.8113e-04 - val_mae: 0.0255
# Epoch 163/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5877e-04 - mae: 0.0151 - val_loss: 5.8289e-04 - val_mae: 0.0256
# Epoch 164/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0671e-04 - mae: 0.0155 - val_loss: 5.9652e-04 - val_mae: 0.0264
# Epoch 165/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4463e-04 - mae: 0.0144 - val_loss: 5.9740e-04 - val_mae: 0.0264
# Epoch 166/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6891e-04 - mae: 0.0146 - val_loss: 7.7881e-04 - val_mae: 0.0296
# Epoch 167/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7528e-04 - mae: 0.0155 - val_loss: 5.9987e-04 - val_mae: 0.0264
# Epoch 168/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.9313e-04 - mae: 0.0152 - val_loss: 5.8645e-04 - val_mae: 0.0255
# Epoch 169/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5876e-04 - mae: 0.0150 - val_loss: 6.5664e-04 - val_mae: 0.0282
# Epoch 170/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2509e-04 - mae: 0.0167 - val_loss: 6.0296e-04 - val_mae: 0.0265
# Epoch 171/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6068e-04 - mae: 0.0147 - val_loss: 5.8498e-04 - val_mae: 0.0259
# Epoch 172/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6550e-04 - mae: 0.0148 - val_loss: 8.2232e-04 - val_mae: 0.0306
# Epoch 173/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0679e-04 - mae: 0.0158 - val_loss: 6.3264e-04 - val_mae: 0.0274
# Epoch 174/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5095e-04 - mae: 0.0141 - val_loss: 5.8074e-04 - val_mae: 0.0257
# Epoch 175/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6539e-04 - mae: 0.0151 - val_loss: 6.2507e-04 - val_mae: 0.0273
# Epoch 176/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3905e-04 - mae: 0.0139 - val_loss: 5.7107e-04 - val_mae: 0.0255
# Epoch 177/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6276e-04 - mae: 0.0150 - val_loss: 6.7184e-04 - val_mae: 0.0288
# Epoch 178/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.0059e-04 - mae: 0.0156 - val_loss: 7.4266e-04 - val_mae: 0.0307
# Epoch 179/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8565e-04 - mae: 0.0158 - val_loss: 9.6874e-04 - val_mae: 0.0364
# Epoch 180/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2291e-04 - mae: 0.0156 - val_loss: 5.8321e-04 - val_mae: 0.0255
# Epoch 181/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7221e-04 - mae: 0.0151 - val_loss: 6.4545e-04 - val_mae: 0.0280
# Epoch 182/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5448e-04 - mae: 0.0149 - val_loss: 6.3351e-04 - val_mae: 0.0264
# Epoch 183/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2960e-04 - mae: 0.0162 - val_loss: 5.7690e-04 - val_mae: 0.0253
# Epoch 184/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4440e-04 - mae: 0.0144 - val_loss: 5.7315e-04 - val_mae: 0.0255
# Epoch 185/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9180e-04 - mae: 0.0152 - val_loss: 5.6468e-04 - val_mae: 0.0255
# Epoch 186/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4568e-04 - mae: 0.0142 - val_loss: 6.0630e-04 - val_mae: 0.0265
# Epoch 187/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4872e-04 - mae: 0.0146 - val_loss: 6.5699e-04 - val_mae: 0.0282
# Epoch 188/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2262e-04 - mae: 0.0144 - val_loss: 6.0996e-04 - val_mae: 0.0266
# Epoch 189/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3809e-04 - mae: 0.0145 - val_loss: 5.9291e-04 - val_mae: 0.0263
# Epoch 190/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6736e-04 - mae: 0.0151 - val_loss: 5.9767e-04 - val_mae: 0.0256
# Epoch 191/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6916e-04 - mae: 0.0146 - val_loss: 6.4860e-04 - val_mae: 0.0279
# Epoch 192/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3248e-04 - mae: 0.0143 - val_loss: 5.7778e-04 - val_mae: 0.0253
# Epoch 193/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4517e-04 - mae: 0.0147 - val_loss: 5.7067e-04 - val_mae: 0.0254
# Epoch 194/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4520e-04 - mae: 0.0144 - val_loss: 7.7137e-04 - val_mae: 0.0316
# Epoch 195/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6020e-04 - mae: 0.0153 - val_loss: 5.7684e-04 - val_mae: 0.0253
# Epoch 196/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5524e-04 - mae: 0.0144 - val_loss: 5.8724e-04 - val_mae: 0.0262
# Epoch 197/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6122e-04 - mae: 0.0149 - val_loss: 5.6021e-04 - val_mae: 0.0252
# Epoch 198/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5307e-04 - mae: 0.0166 - val_loss: 5.6667e-04 - val_mae: 0.0253
# Epoch 199/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6948e-04 - mae: 0.0149 - val_loss: 6.9646e-04 - val_mae: 0.0278
# Epoch 200/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5946e-04 - mae: 0.0146 - val_loss: 7.7124e-04 - val_mae: 0.0315
# Epoch 201/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4440e-04 - mae: 0.0144 - val_loss: 5.9617e-04 - val_mae: 0.0256
# Epoch 202/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3991e-04 - mae: 0.0145 - val_loss: 5.7863e-04 - val_mae: 0.0257
# Epoch 203/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6907e-04 - mae: 0.0150 - val_loss: 5.9188e-04 - val_mae: 0.0262
# Epoch 204/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4410e-04 - mae: 0.0144 - val_loss: 5.7933e-04 - val_mae: 0.0254
# Epoch 205/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5991e-04 - mae: 0.0146 - val_loss: 6.1591e-04 - val_mae: 0.0261
# Epoch 206/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4305e-04 - mae: 0.0144 - val_loss: 6.5530e-04 - val_mae: 0.0283
# Epoch 207/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9401e-04 - mae: 0.0153 - val_loss: 5.6670e-04 - val_mae: 0.0253
# Epoch 208/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3174e-04 - mae: 0.0143 - val_loss: 5.6068e-04 - val_mae: 0.0251
# Epoch 209/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5810e-04 - mae: 0.0152 - val_loss: 5.6551e-04 - val_mae: 0.0253
# Epoch 210/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6009e-04 - mae: 0.0145 - val_loss: 5.6936e-04 - val_mae: 0.0256
# Epoch 211/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9053e-04 - mae: 0.0153 - val_loss: 6.1650e-04 - val_mae: 0.0260
# Epoch 212/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5513e-04 - mae: 0.0144 - val_loss: 5.7263e-04 - val_mae: 0.0253
# Epoch 213/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2507e-04 - mae: 0.0139 - val_loss: 6.4840e-04 - val_mae: 0.0267
# Epoch 214/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5366e-04 - mae: 0.0149 - val_loss: 7.0561e-04 - val_mae: 0.0297
# Epoch 215/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3781e-04 - mae: 0.0142 - val_loss: 6.5306e-04 - val_mae: 0.0269
# Epoch 216/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4694e-04 - mae: 0.0149 - val_loss: 6.8522e-04 - val_mae: 0.0275
# Epoch 217/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8631e-04 - mae: 0.0149 - val_loss: 6.2179e-04 - val_mae: 0.0261
# Epoch 218/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0277e-04 - mae: 0.0151 - val_loss: 5.7623e-04 - val_mae: 0.0254
# Epoch 219/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6030e-04 - mae: 0.0147 - val_loss: 5.9760e-04 - val_mae: 0.0266
# Epoch 220/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2297e-04 - mae: 0.0139 - val_loss: 6.5619e-04 - val_mae: 0.0283
# Epoch 221/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7862e-04 - mae: 0.0150 - val_loss: 9.1440e-04 - val_mae: 0.0350
# Epoch 222/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5205e-04 - mae: 0.0148 - val_loss: 6.0789e-04 - val_mae: 0.0260
# Epoch 223/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5458e-04 - mae: 0.0141 - val_loss: 5.6965e-04 - val_mae: 0.0255
# Epoch 224/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6393e-04 - mae: 0.0146 - val_loss: 9.6192e-04 - val_mae: 0.0364
# Epoch 225/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4308e-04 - mae: 0.0174 - val_loss: 6.7173e-04 - val_mae: 0.0288
# Epoch 226/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5520e-04 - mae: 0.0145 - val_loss: 5.9156e-04 - val_mae: 0.0255
# Epoch 227/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3642e-04 - mae: 0.0141 - val_loss: 8.5159e-04 - val_mae: 0.0315
# Epoch 228/500
# ...
# Epoch 52/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8631e-04 - mae: 0.0156 - val_loss: 6.1334e-04 - val_mae: 0.0263
# Epoch 53/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7360e-04 - mae: 0.0149 - val_loss: 6.6924e-04 - val_mae: 0.0283
# Epoch 54/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5404e-04 - mae: 0.0146 - val_loss: 6.0671e-04 - val_mae: 0.0259
# Epoch 55/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0044e-04 - mae: 0.0154 - val_loss: 6.0841e-04 - val_mae: 0.0258
# Epoch 56/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8285e-04 - mae: 0.0148 - val_loss: 6.6585e-04 - val_mae: 0.0283
# Epoch 57/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4341e-04 - mae: 0.0148 - val_loss: 6.0671e-04 - val_mae: 0.0262
# Epoch 58/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5282e-04 - mae: 0.0170 - val_loss: 6.6787e-04 - val_mae: 0.0282
# Epoch 59/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6651e-04 - mae: 0.0172 - val_loss: 0.0011 - val_mae: 0.0393
# Epoch 60/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5572e-04 - mae: 0.0169 - val_loss: 7.2395e-04 - val_mae: 0.0275
# Epoch 61/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1946e-04 - mae: 0.0169 - val_loss: 6.2551e-04 - val_mae: 0.0270
# Epoch 62/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0486e-04 - mae: 0.0160 - val_loss: 6.2540e-04 - val_mae: 0.0269
# Epoch 63/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5028e-04 - mae: 0.0145 - val_loss: 6.7643e-04 - val_mae: 0.0287
# Epoch 64/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9057e-04 - mae: 0.0157 - val_loss: 6.2230e-04 - val_mae: 0.0259
# Epoch 65/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5556e-04 - mae: 0.0152 - val_loss: 9.8867e-04 - val_mae: 0.0368
# Epoch 66/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8005e-04 - mae: 0.0154 - val_loss: 6.3397e-04 - val_mae: 0.0272
# Epoch 67/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.9705e-04 - mae: 0.0158 - val_loss: 6.3000e-04 - val_mae: 0.0272
# Epoch 68/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8302e-04 - mae: 0.0154 - val_loss: 6.4008e-04 - val_mae: 0.0275
# Epoch 69/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.1022e-04 - mae: 0.0154 - val_loss: 6.5666e-04 - val_mae: 0.0280
# Epoch 70/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1304e-04 - mae: 0.0159 - val_loss: 6.0727e-04 - val_mae: 0.0255
# Epoch 71/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.4706e-04 - mae: 0.0168 - val_loss: 7.0005e-04 - val_mae: 0.0270
# Epoch 72/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0883e-04 - mae: 0.0158 - val_loss: 6.2579e-04 - val_mae: 0.0259
# Epoch 73/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1817e-04 - mae: 0.0162 - val_loss: 6.7259e-04 - val_mae: 0.0285
# Epoch 74/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2974e-04 - mae: 0.0173 - val_loss: 7.5062e-04 - val_mae: 0.0307
# Epoch 75/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8586e-04 - mae: 0.0155 - val_loss: 0.0012 - val_mae: 0.0411
# Epoch 76/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9528e-04 - mae: 0.0163 - val_loss: 6.3141e-04 - val_mae: 0.0259
# Epoch 77/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.0693e-04 - mae: 0.0160 - val_loss: 6.2233e-04 - val_mae: 0.0266
# Epoch 78/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3699e-04 - mae: 0.0148 - val_loss: 6.3320e-04 - val_mae: 0.0274
# Epoch 79/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7983e-04 - mae: 0.0157 - val_loss: 8.7800e-04 - val_mae: 0.0310
# Epoch 80/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.3492e-04 - mae: 0.0158 - val_loss: 6.2166e-04 - val_mae: 0.0257
# Epoch 81/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9427e-04 - mae: 0.0156 - val_loss: 6.2876e-04 - val_mae: 0.0258
# Epoch 82/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.5944e-04 - mae: 0.0151 - val_loss: 6.3370e-04 - val_mae: 0.0259
# Epoch 83/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.8734e-04 - mae: 0.0158 - val_loss: 7.9121e-04 - val_mae: 0.0289
# Epoch 84/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0200e-04 - mae: 0.0156 - val_loss: 6.3572e-04 - val_mae: 0.0274
# Epoch 85/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5038e-04 - mae: 0.0148 - val_loss: 7.2437e-04 - val_mae: 0.0275
# Epoch 86/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5739e-04 - mae: 0.0151 - val_loss: 6.2232e-04 - val_mae: 0.0257
# Epoch 87/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8920e-04 - mae: 0.0155 - val_loss: 6.2428e-04 - val_mae: 0.0271
# Epoch 88/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.9780e-04 - mae: 0.0160 - val_loss: 6.0305e-04 - val_mae: 0.0255
# Epoch 89/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7799e-04 - mae: 0.0157 - val_loss: 8.7316e-04 - val_mae: 0.0307
# Epoch 90/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5720e-04 - mae: 0.0145 - val_loss: 6.0319e-04 - val_mae: 0.0261
# Epoch 91/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6522e-04 - mae: 0.0149 - val_loss: 6.2402e-04 - val_mae: 0.0261
# Epoch 92/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8198e-04 - mae: 0.0150 - val_loss: 7.2300e-04 - val_mae: 0.0274
# Epoch 93/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9785e-04 - mae: 0.0154 - val_loss: 6.1852e-04 - val_mae: 0.0265
# Epoch 94/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4818e-04 - mae: 0.0144 - val_loss: 8.1154e-04 - val_mae: 0.0293
# Epoch 95/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2906e-04 - mae: 0.0173 - val_loss: 6.2573e-04 - val_mae: 0.0258
# Epoch 96/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9230e-04 - mae: 0.0153 - val_loss: 6.8480e-04 - val_mae: 0.0267
# Epoch 97/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9314e-04 - mae: 0.0158 - val_loss: 5.9754e-04 - val_mae: 0.0256
# Epoch 98/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3465e-04 - mae: 0.0144 - val_loss: 6.1788e-04 - val_mae: 0.0267
# Epoch 99/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7004e-04 - mae: 0.0149 - val_loss: 6.0362e-04 - val_mae: 0.0259
# Epoch 100/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0258e-04 - mae: 0.0157 - val_loss: 6.0354e-04 - val_mae: 0.0265
# Epoch 101/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9450e-04 - mae: 0.0151 - val_loss: 5.9435e-04 - val_mae: 0.0256
# Epoch 102/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5678e-04 - mae: 0.0148 - val_loss: 6.6882e-04 - val_mae: 0.0289
# Epoch 103/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0410e-04 - mae: 0.0165 - val_loss: 6.0567e-04 - val_mae: 0.0262
# Epoch 104/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5975e-04 - mae: 0.0160 - val_loss: 6.2508e-04 - val_mae: 0.0258
# Epoch 105/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5161e-04 - mae: 0.0148 - val_loss: 6.2389e-04 - val_mae: 0.0266
# Epoch 106/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2823e-04 - mae: 0.0143 - val_loss: 5.9762e-04 - val_mae: 0.0262
# Epoch 107/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3960e-04 - mae: 0.0141 - val_loss: 7.5087e-04 - val_mae: 0.0311
# Epoch 108/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9148e-04 - mae: 0.0155 - val_loss: 7.6945e-04 - val_mae: 0.0316
# Epoch 109/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1935e-04 - mae: 0.0138 - val_loss: 6.1159e-04 - val_mae: 0.0267
# Epoch 110/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7539e-04 - mae: 0.0149 - val_loss: 8.9984e-04 - val_mae: 0.0351
# Epoch 111/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7748e-04 - mae: 0.0156 - val_loss: 6.6417e-04 - val_mae: 0.0285
# Epoch 112/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3001e-04 - mae: 0.0170 - val_loss: 6.1022e-04 - val_mae: 0.0257
# Epoch 113/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8222e-04 - mae: 0.0156 - val_loss: 6.2027e-04 - val_mae: 0.0257
# Epoch 114/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9642e-04 - mae: 0.0159 - val_loss: 6.4428e-04 - val_mae: 0.0260
# Epoch 115/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9273e-04 - mae: 0.0157 - val_loss: 9.4230e-04 - val_mae: 0.0360
# Epoch 116/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7715e-04 - mae: 0.0152 - val_loss: 7.1190e-04 - val_mae: 0.0273
# Epoch 117/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6753e-04 - mae: 0.0151 - val_loss: 6.7841e-04 - val_mae: 0.0290
# Epoch 118/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6058e-04 - mae: 0.0148 - val_loss: 6.7108e-04 - val_mae: 0.0286
# Epoch 119/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9493e-04 - mae: 0.0154 - val_loss: 0.0010 - val_mae: 0.0381
# Epoch 120/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1023e-04 - mae: 0.0170 - val_loss: 6.8031e-04 - val_mae: 0.0289
# Epoch 121/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0430e-04 - mae: 0.0161 - val_loss: 7.2457e-04 - val_mae: 0.0273
# Epoch 122/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9417e-04 - mae: 0.0157 - val_loss: 6.1985e-04 - val_mae: 0.0259
# Epoch 123/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6134e-04 - mae: 0.0148 - val_loss: 6.3317e-04 - val_mae: 0.0276
# Epoch 124/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7708e-04 - mae: 0.0150 - val_loss: 6.3617e-04 - val_mae: 0.0273
# Epoch 125/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3214e-04 - mae: 0.0142 - val_loss: 6.0553e-04 - val_mae: 0.0256
# Epoch 126/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8162e-04 - mae: 0.0148 - val_loss: 6.6080e-04 - val_mae: 0.0283
# Epoch 127/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6098e-04 - mae: 0.0155 - val_loss: 5.9265e-04 - val_mae: 0.0256
# Epoch 128/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3988e-04 - mae: 0.0164 - val_loss: 6.3144e-04 - val_mae: 0.0263
# Epoch 129/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3608e-04 - mae: 0.0161 - val_loss: 6.2499e-04 - val_mae: 0.0271
# Epoch 130/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5145e-04 - mae: 0.0148 - val_loss: 6.5134e-04 - val_mae: 0.0281
# Epoch 131/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5639e-04 - mae: 0.0149 - val_loss: 6.0373e-04 - val_mae: 0.0259
# Epoch 132/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3588e-04 - mae: 0.0148 - val_loss: 7.0652e-04 - val_mae: 0.0271
# Epoch 133/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6337e-04 - mae: 0.0150 - val_loss: 6.1838e-04 - val_mae: 0.0269
# Epoch 134/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0141e-04 - mae: 0.0157 - val_loss: 7.3931e-04 - val_mae: 0.0309
# Epoch 135/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4569e-04 - mae: 0.0149 - val_loss: 0.0014 - val_mae: 0.0468
# Epoch 136/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5875e-04 - mae: 0.0150 - val_loss: 0.0012 - val_mae: 0.0408
# Epoch 137/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5615e-04 - mae: 0.0171 - val_loss: 8.2575e-04 - val_mae: 0.0331
# Epoch 138/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5935e-04 - mae: 0.0149 - val_loss: 6.5213e-04 - val_mae: 0.0277
# Epoch 139/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4325e-04 - mae: 0.0143 - val_loss: 6.5335e-04 - val_mae: 0.0263
# Epoch 140/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5651e-04 - mae: 0.0146 - val_loss: 6.5444e-04 - val_mae: 0.0272
# Epoch 141/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8192e-04 - mae: 0.0158 - val_loss: 6.5974e-04 - val_mae: 0.0285
# Epoch 142/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6873e-04 - mae: 0.0149 - val_loss: 9.2958e-04 - val_mae: 0.0357
# Epoch 143/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5446e-04 - mae: 0.0150 - val_loss: 7.1605e-04 - val_mae: 0.0298
# Epoch 144/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4943e-04 - mae: 0.0146 - val_loss: 0.0010 - val_mae: 0.0384
# Epoch 145/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4590e-04 - mae: 0.0143 - val_loss: 8.9642e-04 - val_mae: 0.0349
# Epoch 146/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5917e-04 - mae: 0.0154 - val_loss: 6.6737e-04 - val_mae: 0.0269
# Epoch 147/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6692e-04 - mae: 0.0150 - val_loss: 0.0011 - val_mae: 0.0395
# Epoch 148/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3467e-04 - mae: 0.0146 - val_loss: 7.0163e-04 - val_mae: 0.0295
# Epoch 149/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3768e-04 - mae: 0.0141 - val_loss: 6.5079e-04 - val_mae: 0.0263
# Epoch 150/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6800e-04 - mae: 0.0152 - val_loss: 8.8315e-04 - val_mae: 0.0346
# Epoch 151/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7700e-04 - mae: 0.0153 - val_loss: 6.7494e-04 - val_mae: 0.0267
# Epoch 152/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5814e-04 - mae: 0.0147 - val_loss: 6.2700e-04 - val_mae: 0.0260
# Epoch 153/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7992e-04 - mae: 0.0147 - val_loss: 7.3166e-04 - val_mae: 0.0301
# Epoch 154/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6896e-04 - mae: 0.0154 - val_loss: 6.4093e-04 - val_mae: 0.0268
# Epoch 155/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8610e-04 - mae: 0.0154 - val_loss: 6.9440e-04 - val_mae: 0.0276
# Epoch 156/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3873e-04 - mae: 0.0145 - val_loss: 6.6344e-04 - val_mae: 0.0281
# Epoch 157/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2597e-04 - mae: 0.0142 - val_loss: 0.0013 - val_mae: 0.0426
# Epoch 158/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8880e-04 - mae: 0.0161 - val_loss: 8.8815e-04 - val_mae: 0.0347
# Epoch 159/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7688e-04 - mae: 0.0153 - val_loss: 6.7044e-04 - val_mae: 0.0269
# Epoch 160/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3244e-04 - mae: 0.0139 - val_loss: 6.6751e-04 - val_mae: 0.0266
# Epoch 161/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2061e-04 - mae: 0.0140 - val_loss: 8.5197e-04 - val_mae: 0.0338
# Epoch 162/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4535e-04 - mae: 0.0144 - val_loss: 8.7546e-04 - val_mae: 0.0340
# Epoch 163/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1814e-04 - mae: 0.0139 - val_loss: 0.0011 - val_mae: 0.0400
# Epoch 164/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8229e-04 - mae: 0.0157 - val_loss: 9.2815e-04 - val_mae: 0.0357
# Epoch 165/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5352e-04 - mae: 0.0150 - val_loss: 8.2621e-04 - val_mae: 0.0292
# Epoch 166/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8215e-04 - mae: 0.0157 - val_loss: 7.1611e-04 - val_mae: 0.0298
# Epoch 167/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0523e-04 - mae: 0.0136 - val_loss: 6.6210e-04 - val_mae: 0.0271
# Epoch 168/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3411e-04 - mae: 0.0148 - val_loss: 6.9874e-04 - val_mae: 0.0272
# Epoch 169/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4778e-04 - mae: 0.0146 - val_loss: 7.2373e-04 - val_mae: 0.0299
# Epoch 170/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3872e-04 - mae: 0.0147 - val_loss: 8.2755e-04 - val_mae: 0.0331
# Epoch 171/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4080e-04 - mae: 0.0144 - val_loss: 6.6055e-04 - val_mae: 0.0276
# Epoch 172/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1270e-04 - mae: 0.0139 - val_loss: 7.4632e-04 - val_mae: 0.0306
# Epoch 173/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4171e-04 - mae: 0.0148 - val_loss: 6.6230e-04 - val_mae: 0.0281
# Epoch 174/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4503e-04 - mae: 0.0147 - val_loss: 6.5202e-04 - val_mae: 0.0268
# Epoch 175/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1668e-04 - mae: 0.0140 - val_loss: 8.1461e-04 - val_mae: 0.0325
# Epoch 176/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5918e-04 - mae: 0.0150 - val_loss: 7.9080e-04 - val_mae: 0.0320
# Epoch 177/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2967e-04 - mae: 0.0143 - val_loss: 7.4937e-04 - val_mae: 0.0281
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
results_n_steps_experiments = pd.DataFrame(results_n_steps_experiments)

# %%
results_n_steps_experiments
# Out:
#    n_steps  weeks  n_seq  weeks_per_seq    Val MAE   Val RMSE    Val R2  \
# 0        5    1.0      1            1.0  13.404014  18.017908  0.953517
# 1       10    2.0      2            1.0  13.272620  17.631719  0.954780
# 2       15    3.0      3            1.0  13.220928  17.690296  0.954102
# 3       20    4.0      4            1.0  13.168772  17.673838  0.953576
# 4       30    6.0      6            1.0  13.458464  18.135052  0.950421
#
#    Val MAPE  Test MAE  Test RMSE   Test R2  Test MAPE
# 0  2.174349  8.786294  12.785748  0.980463   1.701196
# 1  2.145709  8.651763  12.672173  0.980730   1.673676
# 2  2.138656  9.062549  13.263285  0.978806   1.764497
# 3  2.128122  8.806970  13.038405  0.979433   1.704146
# 4  2.168733  9.265101  13.338268  0.978383   1.807208

# %% [markdown]
# ## Result

# %%
model_cnnlstm, predictor_cnnlstm, history_cnnlstm, X_train_cnnlstm, y_train_cnnlstm, X_val_cnnlstm, y_val_cnnlstm, X_test_cnnlstm, y_test_cnnlstm = CNNLSTMforecasting(df, n_steps= 10, n_seq= 2)
# Out:
# Epoch 1/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0275 - mae: 0.1490 - val_loss: 0.0017 - val_mae: 0.0482
# Epoch 2/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6110e-04 - mae: 0.0268 - val_loss: 0.0021 - val_mae: 0.0560
# Epoch 3/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4502e-04 - mae: 0.0246 - val_loss: 0.0017 - val_mae: 0.0496
# Epoch 4/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5404e-04 - mae: 0.0219 - val_loss: 0.0015 - val_mae: 0.0444
# Epoch 5/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7306e-04 - mae: 0.0197 - val_loss: 0.0013 - val_mae: 0.0407
# Epoch 6/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6570e-04 - mae: 0.0202 - val_loss: 0.0012 - val_mae: 0.0356
# Epoch 7/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4230e-04 - mae: 0.0192 - val_loss: 0.0013 - val_mae: 0.0422
# Epoch 8/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9001e-04 - mae: 0.0201 - val_loss: 0.0010 - val_mae: 0.0342
# Epoch 9/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3516e-04 - mae: 0.0196 - val_loss: 0.0011 - val_mae: 0.0377
# Epoch 10/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1183e-04 - mae: 0.0189 - val_loss: 0.0013 - val_mae: 0.0417
# Epoch 11/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6058e-04 - mae: 0.0178 - val_loss: 8.7072e-04 - val_mae: 0.0309
# Epoch 12/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5097e-04 - mae: 0.0193 - val_loss: 8.1489e-04 - val_mae: 0.0303
# Epoch 13/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0979e-04 - mae: 0.0181 - val_loss: 7.5743e-04 - val_mae: 0.0293
# Epoch 14/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2461e-04 - mae: 0.0172 - val_loss: 0.0011 - val_mae: 0.0382
# Epoch 15/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6803e-04 - mae: 0.0179 - val_loss: 7.4064e-04 - val_mae: 0.0281
# Epoch 16/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3157e-04 - mae: 0.0171 - val_loss: 7.0635e-04 - val_mae: 0.0286
# Epoch 17/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4107e-04 - mae: 0.0171 - val_loss: 7.0388e-04 - val_mae: 0.0275
# Epoch 18/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4835e-04 - mae: 0.0173 - val_loss: 7.0029e-04 - val_mae: 0.0285
# Epoch 19/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6804e-04 - mae: 0.0178 - val_loss: 7.2586e-04 - val_mae: 0.0295
# Epoch 20/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3002e-04 - mae: 0.0169 - val_loss: 6.9874e-04 - val_mae: 0.0287
# Epoch 21/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4072e-04 - mae: 0.0169 - val_loss: 6.8442e-04 - val_mae: 0.0280
# Epoch 22/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8611e-04 - mae: 0.0176 - val_loss: 8.7995e-04 - val_mae: 0.0307
# Epoch 23/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1738e-04 - mae: 0.0173 - val_loss: 7.4856e-04 - val_mae: 0.0303
# Epoch 24/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2851e-04 - mae: 0.0167 - val_loss: 8.9810e-04 - val_mae: 0.0342
# Epoch 25/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4864e-04 - mae: 0.0171 - val_loss: 0.0010 - val_mae: 0.0377
# Epoch 26/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2689e-04 - mae: 0.0169 - val_loss: 7.0870e-04 - val_mae: 0.0291
# Epoch 27/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9235e-04 - mae: 0.0162 - val_loss: 0.0013 - val_mae: 0.0440
# Epoch 28/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0783e-04 - mae: 0.0170 - val_loss: 6.9300e-04 - val_mae: 0.0286
# Epoch 29/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1560e-04 - mae: 0.0165 - val_loss: 7.5567e-04 - val_mae: 0.0283
# Epoch 30/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2635e-04 - mae: 0.0167 - val_loss: 7.2125e-04 - val_mae: 0.0296
# Epoch 31/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4137e-04 - mae: 0.0172 - val_loss: 6.8171e-04 - val_mae: 0.0274
# Epoch 32/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1787e-04 - mae: 0.0165 - val_loss: 7.1869e-04 - val_mae: 0.0295
# Epoch 33/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0919e-04 - mae: 0.0162 - val_loss: 6.5434e-04 - val_mae: 0.0273
# Epoch 34/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0555e-04 - mae: 0.0163 - val_loss: 6.5763e-04 - val_mae: 0.0273
# Epoch 35/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8456e-04 - mae: 0.0161 - val_loss: 8.3795e-04 - val_mae: 0.0329
# Epoch 36/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1162e-04 - mae: 0.0164 - val_loss: 6.6562e-04 - val_mae: 0.0274
# Epoch 37/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3185e-04 - mae: 0.0169 - val_loss: 9.0918e-04 - val_mae: 0.0347
# Epoch 38/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7615e-04 - mae: 0.0178 - val_loss: 6.6827e-04 - val_mae: 0.0272
# Epoch 39/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7639e-04 - mae: 0.0157 - val_loss: 6.5615e-04 - val_mae: 0.0273
# Epoch 40/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0781e-04 - mae: 0.0161 - val_loss: 6.5566e-04 - val_mae: 0.0275
# Epoch 41/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0119e-04 - mae: 0.0159 - val_loss: 6.7401e-04 - val_mae: 0.0281
# Epoch 42/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0938e-04 - mae: 0.0177 - val_loss: 6.8462e-04 - val_mae: 0.0285
# Epoch 43/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9066e-04 - mae: 0.0155 - val_loss: 6.6871e-04 - val_mae: 0.0271
# Epoch 44/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9997e-04 - mae: 0.0158 - val_loss: 6.9758e-04 - val_mae: 0.0273
# Epoch 45/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0199e-04 - mae: 0.0188 - val_loss: 6.6718e-04 - val_mae: 0.0268
# Epoch 46/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6121e-04 - mae: 0.0175 - val_loss: 6.5868e-04 - val_mae: 0.0268
# Epoch 47/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3108e-04 - mae: 0.0165 - val_loss: 6.7536e-04 - val_mae: 0.0283
# Epoch 48/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1130e-04 - mae: 0.0160 - val_loss: 6.4163e-04 - val_mae: 0.0269
# Epoch 49/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9168e-04 - mae: 0.0153 - val_loss: 6.6832e-04 - val_mae: 0.0269
# Epoch 50/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7128e-04 - mae: 0.0156 - val_loss: 6.5157e-04 - val_mae: 0.0266
# Epoch 51/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0037e-04 - mae: 0.0160 - val_loss: 7.0681e-04 - val_mae: 0.0294
# Epoch 52/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9482e-04 - mae: 0.0157 - val_loss: 6.3332e-04 - val_mae: 0.0268
# Epoch 53/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9970e-04 - mae: 0.0155 - val_loss: 6.3966e-04 - val_mae: 0.0269
# Epoch 54/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0971e-04 - mae: 0.0161 - val_loss: 6.7697e-04 - val_mae: 0.0284
# Epoch 55/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0297e-04 - mae: 0.0159 - val_loss: 8.0706e-04 - val_mae: 0.0321
# Epoch 56/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0559e-04 - mae: 0.0160 - val_loss: 6.5899e-04 - val_mae: 0.0276
# Epoch 57/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0100e-04 - mae: 0.0153 - val_loss: 6.4745e-04 - val_mae: 0.0274
# Epoch 58/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0093e-04 - mae: 0.0157 - val_loss: 6.6943e-04 - val_mae: 0.0267
# Epoch 59/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7878e-04 - mae: 0.0155 - val_loss: 6.8084e-04 - val_mae: 0.0269
# Epoch 60/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8906e-04 - mae: 0.0154 - val_loss: 6.2356e-04 - val_mae: 0.0264
# Epoch 61/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1919e-04 - mae: 0.0160 - val_loss: 7.1377e-04 - val_mae: 0.0276
# Epoch 62/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6945e-04 - mae: 0.0152 - val_loss: 6.3904e-04 - val_mae: 0.0269
# Epoch 63/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0341e-04 - mae: 0.0158 - val_loss: 8.7980e-04 - val_mae: 0.0310
# Epoch 64/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2928e-04 - mae: 0.0177 - val_loss: 6.4365e-04 - val_mae: 0.0272
# Epoch 65/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6811e-04 - mae: 0.0154 - val_loss: 6.8473e-04 - val_mae: 0.0287
# Epoch 66/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2417e-04 - mae: 0.0158 - val_loss: 8.3049e-04 - val_mae: 0.0328
# Epoch 67/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1265e-04 - mae: 0.0161 - val_loss: 6.6067e-04 - val_mae: 0.0267
# Epoch 68/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4070e-04 - mae: 0.0144 - val_loss: 6.2889e-04 - val_mae: 0.0261
# Epoch 69/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5595e-04 - mae: 0.0146 - val_loss: 6.5662e-04 - val_mae: 0.0266
# Epoch 70/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2317e-04 - mae: 0.0162 - val_loss: 6.3997e-04 - val_mae: 0.0266
# Epoch 71/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9772e-04 - mae: 0.0159 - val_loss: 6.2517e-04 - val_mae: 0.0265
# Epoch 72/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9584e-04 - mae: 0.0153 - val_loss: 7.0533e-04 - val_mae: 0.0294
# Epoch 73/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7643e-04 - mae: 0.0151 - val_loss: 8.3996e-04 - val_mae: 0.0303
# Epoch 74/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2610e-04 - mae: 0.0158 - val_loss: 6.2743e-04 - val_mae: 0.0266
# Epoch 75/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8421e-04 - mae: 0.0151 - val_loss: 6.1384e-04 - val_mae: 0.0261
# Epoch 76/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8754e-04 - mae: 0.0157 - val_loss: 0.0012 - val_mae: 0.0383
# Epoch 77/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4182e-04 - mae: 0.0172 - val_loss: 6.2737e-04 - val_mae: 0.0265
# Epoch 78/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9652e-04 - mae: 0.0149 - val_loss: 6.3392e-04 - val_mae: 0.0262
# Epoch 79/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5814e-04 - mae: 0.0150 - val_loss: 6.2363e-04 - val_mae: 0.0262
# Epoch 80/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0262e-04 - mae: 0.0157 - val_loss: 0.0011 - val_mae: 0.0388
# Epoch 81/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2013e-04 - mae: 0.0160 - val_loss: 6.2813e-04 - val_mae: 0.0263
# Epoch 82/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1555e-04 - mae: 0.0157 - val_loss: 6.3532e-04 - val_mae: 0.0269
# Epoch 83/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4001e-04 - mae: 0.0159 - val_loss: 7.3396e-04 - val_mae: 0.0303
# Epoch 84/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5044e-04 - mae: 0.0169 - val_loss: 6.3723e-04 - val_mae: 0.0273
# Epoch 85/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6296e-04 - mae: 0.0150 - val_loss: 7.1625e-04 - val_mae: 0.0297
# Epoch 86/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7145e-04 - mae: 0.0150 - val_loss: 8.2379e-04 - val_mae: 0.0327
# Epoch 87/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1842e-04 - mae: 0.0158 - val_loss: 8.3193e-04 - val_mae: 0.0303
# Epoch 88/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8025e-04 - mae: 0.0156 - val_loss: 6.2546e-04 - val_mae: 0.0261
# Epoch 89/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1180e-04 - mae: 0.0155 - val_loss: 9.3087e-04 - val_mae: 0.0355
# Epoch 90/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4629e-04 - mae: 0.0168 - val_loss: 6.3420e-04 - val_mae: 0.0262
# Epoch 91/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4521e-04 - mae: 0.0145 - val_loss: 6.2318e-04 - val_mae: 0.0268
# Epoch 92/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0933e-04 - mae: 0.0156 - val_loss: 6.0851e-04 - val_mae: 0.0260
# Epoch 93/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9540e-04 - mae: 0.0162 - val_loss: 7.0525e-04 - val_mae: 0.0276
# Epoch 94/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2860e-04 - mae: 0.0180 - val_loss: 6.2159e-04 - val_mae: 0.0260
# Epoch 95/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6462e-04 - mae: 0.0147 - val_loss: 6.3041e-04 - val_mae: 0.0263
# Epoch 96/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5293e-04 - mae: 0.0149 - val_loss: 6.6544e-04 - val_mae: 0.0282
# Epoch 97/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9953e-04 - mae: 0.0154 - val_loss: 6.1240e-04 - val_mae: 0.0264
# Epoch 98/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5016e-04 - mae: 0.0149 - val_loss: 6.1510e-04 - val_mae: 0.0263
# Epoch 99/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2928e-04 - mae: 0.0159 - val_loss: 6.1572e-04 - val_mae: 0.0262
# Epoch 100/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4103e-04 - mae: 0.0172 - val_loss: 6.0257e-04 - val_mae: 0.0260
# Epoch 101/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9247e-04 - mae: 0.0153 - val_loss: 6.5631e-04 - val_mae: 0.0267
# Epoch 102/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6499e-04 - mae: 0.0168 - val_loss: 6.6375e-04 - val_mae: 0.0268
# Epoch 103/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9918e-04 - mae: 0.0152 - val_loss: 6.3420e-04 - val_mae: 0.0262
# Epoch 104/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7585e-04 - mae: 0.0150 - val_loss: 6.8456e-04 - val_mae: 0.0289
# Epoch 105/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1796e-04 - mae: 0.0156 - val_loss: 6.2631e-04 - val_mae: 0.0260
# Epoch 106/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3725e-04 - mae: 0.0143 - val_loss: 8.0241e-04 - val_mae: 0.0299
# Epoch 107/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0307e-04 - mae: 0.0154 - val_loss: 6.3163e-04 - val_mae: 0.0272
# Epoch 108/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3448e-04 - mae: 0.0142 - val_loss: 0.0012 - val_mae: 0.0411
# Epoch 109/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4170e-04 - mae: 0.0171 - val_loss: 6.2580e-04 - val_mae: 0.0269
# Epoch 110/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3721e-04 - mae: 0.0164 - val_loss: 6.1418e-04 - val_mae: 0.0266
# Epoch 111/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4845e-04 - mae: 0.0147 - val_loss: 7.5872e-04 - val_mae: 0.0310
# Epoch 112/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6820e-04 - mae: 0.0154 - val_loss: 7.3153e-04 - val_mae: 0.0281
# Epoch 113/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5894e-04 - mae: 0.0151 - val_loss: 6.7609e-04 - val_mae: 0.0286
# Epoch 114/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3688e-04 - mae: 0.0144 - val_loss: 6.4080e-04 - val_mae: 0.0276
# Epoch 115/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0688e-04 - mae: 0.0152 - val_loss: 6.6479e-04 - val_mae: 0.0284
# Epoch 116/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6494e-04 - mae: 0.0150 - val_loss: 6.3565e-04 - val_mae: 0.0274
# Epoch 117/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6831e-04 - mae: 0.0147 - val_loss: 5.9274e-04 - val_mae: 0.0258
# Epoch 118/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1300e-04 - mae: 0.0158 - val_loss: 6.0092e-04 - val_mae: 0.0258
# Epoch 119/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8881e-04 - mae: 0.0152 - val_loss: 7.2725e-04 - val_mae: 0.0281
# Epoch 120/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3892e-04 - mae: 0.0142 - val_loss: 7.0743e-04 - val_mae: 0.0296
# Epoch 121/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0814e-04 - mae: 0.0157 - val_loss: 6.4009e-04 - val_mae: 0.0263
# Epoch 122/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5649e-04 - mae: 0.0146 - val_loss: 5.9637e-04 - val_mae: 0.0260
# Epoch 123/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8562e-04 - mae: 0.0153 - val_loss: 6.9721e-04 - val_mae: 0.0274
# Epoch 124/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6163e-04 - mae: 0.0150 - val_loss: 8.5844e-04 - val_mae: 0.0338
# Epoch 125/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9599e-04 - mae: 0.0158 - val_loss: 6.3879e-04 - val_mae: 0.0276
# Epoch 126/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6188e-04 - mae: 0.0147 - val_loss: 6.2947e-04 - val_mae: 0.0273
# Epoch 127/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5852e-04 - mae: 0.0149 - val_loss: 6.2461e-04 - val_mae: 0.0271
# Epoch 128/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6826e-04 - mae: 0.0150 - val_loss: 8.2434e-04 - val_mae: 0.0329
# Epoch 129/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2903e-04 - mae: 0.0157 - val_loss: 6.6138e-04 - val_mae: 0.0283
# Epoch 130/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2656e-04 - mae: 0.0156 - val_loss: 6.4730e-04 - val_mae: 0.0264
# Epoch 131/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3107e-04 - mae: 0.0158 - val_loss: 6.1838e-04 - val_mae: 0.0269
# Epoch 132/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4389e-04 - mae: 0.0143 - val_loss: 5.9845e-04 - val_mae: 0.0262
# Epoch 133/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8724e-04 - mae: 0.0147 - val_loss: 5.9149e-04 - val_mae: 0.0259
# Epoch 134/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8927e-04 - mae: 0.0150 - val_loss: 6.1307e-04 - val_mae: 0.0269
# Epoch 135/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0264e-04 - mae: 0.0158 - val_loss: 8.2394e-04 - val_mae: 0.0328
# Epoch 136/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6451e-04 - mae: 0.0149 - val_loss: 7.5282e-04 - val_mae: 0.0309
# Epoch 137/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5182e-04 - mae: 0.0147 - val_loss: 7.0849e-04 - val_mae: 0.0295
# Epoch 138/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5856e-04 - mae: 0.0148 - val_loss: 0.0012 - val_mae: 0.0424
# Epoch 139/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0095e-04 - mae: 0.0157 - val_loss: 6.2278e-04 - val_mae: 0.0271
# Epoch 140/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1159e-04 - mae: 0.0152 - val_loss: 6.2227e-04 - val_mae: 0.0270
# Epoch 141/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0602e-04 - mae: 0.0154 - val_loss: 7.7813e-04 - val_mae: 0.0315
# Epoch 142/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9963e-04 - mae: 0.0155 - val_loss: 5.8750e-04 - val_mae: 0.0258
# Epoch 143/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.9580e-04 - mae: 0.0149 - val_loss: 5.8247e-04 - val_mae: 0.0257
# Epoch 144/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7904e-04 - mae: 0.0151 - val_loss: 5.9678e-04 - val_mae: 0.0263
# Epoch 145/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6652e-04 - mae: 0.0147 - val_loss: 7.0409e-04 - val_mae: 0.0297
# Epoch 146/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0098e-04 - mae: 0.0156 - val_loss: 5.9710e-04 - val_mae: 0.0255
# Epoch 147/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8151e-04 - mae: 0.0158 - val_loss: 5.9715e-04 - val_mae: 0.0263
# Epoch 148/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3476e-04 - mae: 0.0143 - val_loss: 6.3837e-04 - val_mae: 0.0264
# Epoch 149/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0346e-04 - mae: 0.0155 - val_loss: 5.8319e-04 - val_mae: 0.0254
# Epoch 150/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7360e-04 - mae: 0.0150 - val_loss: 6.1363e-04 - val_mae: 0.0258
# Epoch 151/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.3824e-04 - mae: 0.0144 - val_loss: 5.7384e-04 - val_mae: 0.0252
# Epoch 152/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.8569e-04 - mae: 0.0153 - val_loss: 5.9008e-04 - val_mae: 0.0260
# Epoch 153/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8581e-04 - mae: 0.0152 - val_loss: 5.9629e-04 - val_mae: 0.0264
# Epoch 154/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7982e-04 - mae: 0.0153 - val_loss: 6.5695e-04 - val_mae: 0.0283
# Epoch 155/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5632e-04 - mae: 0.0145 - val_loss: 5.9250e-04 - val_mae: 0.0261
# Epoch 156/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7659e-04 - mae: 0.0148 - val_loss: 5.9738e-04 - val_mae: 0.0264
# Epoch 157/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9660e-04 - mae: 0.0157 - val_loss: 6.2524e-04 - val_mae: 0.0260
# Epoch 158/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7058e-04 - mae: 0.0148 - val_loss: 5.8607e-04 - val_mae: 0.0258
# Epoch 159/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8879e-04 - mae: 0.0148 - val_loss: 6.3169e-04 - val_mae: 0.0263
# Epoch 160/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0104e-04 - mae: 0.0152 - val_loss: 5.7001e-04 - val_mae: 0.0253
# Epoch 161/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5045e-04 - mae: 0.0151 - val_loss: 5.7112e-04 - val_mae: 0.0253
# Epoch 162/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7075e-04 - mae: 0.0154 - val_loss: 5.7587e-04 - val_mae: 0.0253
# Epoch 163/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7902e-04 - mae: 0.0150 - val_loss: 5.7477e-04 - val_mae: 0.0253
# Epoch 164/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7626e-04 - mae: 0.0146 - val_loss: 5.7736e-04 - val_mae: 0.0253
# Epoch 165/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.5469e-04 - mae: 0.0148 - val_loss: 9.8538e-04 - val_mae: 0.0340
# Epoch 166/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0739e-04 - mae: 0.0163 - val_loss: 6.5517e-04 - val_mae: 0.0267
# Epoch 167/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9757e-04 - mae: 0.0153 - val_loss: 6.7396e-04 - val_mae: 0.0289
# Epoch 168/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2716e-04 - mae: 0.0156 - val_loss: 5.6838e-04 - val_mae: 0.0251
# Epoch 169/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5399e-04 - mae: 0.0142 - val_loss: 6.2034e-04 - val_mae: 0.0261
# Epoch 170/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6130e-04 - mae: 0.0148 - val_loss: 6.1272e-04 - val_mae: 0.0259
# Epoch 171/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1848e-04 - mae: 0.0138 - val_loss: 5.8403e-04 - val_mae: 0.0260
# Epoch 172/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5200e-04 - mae: 0.0147 - val_loss: 5.6977e-04 - val_mae: 0.0251
# Epoch 173/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.5108e-04 - mae: 0.0146 - val_loss: 5.7334e-04 - val_mae: 0.0252
# Epoch 174/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.7717e-04 - mae: 0.0146 - val_loss: 6.0445e-04 - val_mae: 0.0256
# Epoch 175/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9071e-04 - mae: 0.0158 - val_loss: 6.3420e-04 - val_mae: 0.0275
# Epoch 176/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5027e-04 - mae: 0.0149 - val_loss: 5.7679e-04 - val_mae: 0.0252
# Epoch 177/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4921e-04 - mae: 0.0139 - val_loss: 6.0176e-04 - val_mae: 0.0265
# Epoch 178/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7436e-04 - mae: 0.0153 - val_loss: 7.6077e-04 - val_mae: 0.0312
# Epoch 179/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.7715e-04 - mae: 0.0150 - val_loss: 6.1970e-04 - val_mae: 0.0272
# Epoch 180/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8337e-04 - mae: 0.0151 - val_loss: 6.3262e-04 - val_mae: 0.0277
# Epoch 181/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9106e-04 - mae: 0.0151 - val_loss: 6.4264e-04 - val_mae: 0.0278
# Epoch 182/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5735e-04 - mae: 0.0150 - val_loss: 5.6714e-04 - val_mae: 0.0253
# Epoch 183/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5027e-04 - mae: 0.0146 - val_loss: 5.7304e-04 - val_mae: 0.0256
# Epoch 184/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2334e-04 - mae: 0.0156 - val_loss: 6.2804e-04 - val_mae: 0.0262
# Epoch 185/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6012e-04 - mae: 0.0149 - val_loss: 5.6374e-04 - val_mae: 0.0253
# Epoch 186/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6042e-04 - mae: 0.0147 - val_loss: 6.1155e-04 - val_mae: 0.0259
# Epoch 187/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6758e-04 - mae: 0.0151 - val_loss: 8.6751e-04 - val_mae: 0.0340
# Epoch 188/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2175e-04 - mae: 0.0163 - val_loss: 5.9275e-04 - val_mae: 0.0254
# Epoch 189/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6242e-04 - mae: 0.0146 - val_loss: 7.4834e-04 - val_mae: 0.0289
# Epoch 190/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6090e-04 - mae: 0.0144 - val_loss: 5.6847e-04 - val_mae: 0.0254
# Epoch 191/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7339e-04 - mae: 0.0146 - val_loss: 5.8969e-04 - val_mae: 0.0255
# Epoch 192/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.8232e-04 - mae: 0.0147 - val_loss: 5.6225e-04 - val_mae: 0.0251
# Epoch 193/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5378e-04 - mae: 0.0152 - val_loss: 5.9532e-04 - val_mae: 0.0266
# Epoch 194/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3076e-04 - mae: 0.0174 - val_loss: 5.9118e-04 - val_mae: 0.0260
# Epoch 195/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2633e-04 - mae: 0.0135 - val_loss: 9.9709e-04 - val_mae: 0.0371
# Epoch 196/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8182e-04 - mae: 0.0153 - val_loss: 5.9385e-04 - val_mae: 0.0256
# Epoch 197/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6453e-04 - mae: 0.0149 - val_loss: 5.8374e-04 - val_mae: 0.0253
# Epoch 198/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9225e-04 - mae: 0.0155 - val_loss: 5.7449e-04 - val_mae: 0.0252
# Epoch 199/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7043e-04 - mae: 0.0145 - val_loss: 5.7639e-04 - val_mae: 0.0257
# Epoch 200/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5172e-04 - mae: 0.0147 - val_loss: 6.1569e-04 - val_mae: 0.0260
# Epoch 201/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4657e-04 - mae: 0.0148 - val_loss: 6.3275e-04 - val_mae: 0.0276
# Epoch 202/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5271e-04 - mae: 0.0147 - val_loss: 5.5425e-04 - val_mae: 0.0250
# Epoch 203/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7240e-04 - mae: 0.0152 - val_loss: 5.5831e-04 - val_mae: 0.0251
# Epoch 204/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5938e-04 - mae: 0.0148 - val_loss: 5.8214e-04 - val_mae: 0.0253
# Epoch 205/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.6436e-04 - mae: 0.0147 - val_loss: 5.6920e-04 - val_mae: 0.0256
# Epoch 206/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4149e-04 - mae: 0.0143 - val_loss: 5.7008e-04 - val_mae: 0.0252
# Epoch 207/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9224e-04 - mae: 0.0154 - val_loss: 6.4750e-04 - val_mae: 0.0266
# Epoch 208/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4198e-04 - mae: 0.0145 - val_loss: 5.5490e-04 - val_mae: 0.0248
# Epoch 209/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5823e-04 - mae: 0.0147 - val_loss: 5.7790e-04 - val_mae: 0.0259
# Epoch 210/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6165e-04 - mae: 0.0142 - val_loss: 6.7881e-04 - val_mae: 0.0290
# Epoch 211/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0494e-04 - mae: 0.0153 - val_loss: 5.7030e-04 - val_mae: 0.0251
# Epoch 212/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3463e-04 - mae: 0.0141 - val_loss: 6.1211e-04 - val_mae: 0.0269
# Epoch 213/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0900e-04 - mae: 0.0155 - val_loss: 8.4325e-04 - val_mae: 0.0333
# Epoch 214/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6240e-04 - mae: 0.0146 - val_loss: 5.7427e-04 - val_mae: 0.0252
# Epoch 215/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6110e-04 - mae: 0.0146 - val_loss: 5.6504e-04 - val_mae: 0.0252
# Epoch 216/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9495e-04 - mae: 0.0149 - val_loss: 5.6657e-04 - val_mae: 0.0253
# Epoch 217/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1603e-04 - mae: 0.0134 - val_loss: 5.8097e-04 - val_mae: 0.0259
# Epoch 218/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4868e-04 - mae: 0.0143 - val_loss: 6.2091e-04 - val_mae: 0.0272
# Epoch 219/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5603e-04 - mae: 0.0148 - val_loss: 5.7596e-04 - val_mae: 0.0254
# Epoch 220/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7001e-04 - mae: 0.0148 - val_loss: 6.0951e-04 - val_mae: 0.0259
# Epoch 221/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7830e-04 - mae: 0.0154 - val_loss: 5.9901e-04 - val_mae: 0.0264
# Epoch 222/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7228e-04 - mae: 0.0149 - val_loss: 5.8432e-04 - val_mae: 0.0259
# Epoch 223/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7846e-04 - mae: 0.0148 - val_loss: 5.7368e-04 - val_mae: 0.0254
# Epoch 224/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.8107e-04 - mae: 0.0154 - val_loss: 6.0129e-04 - val_mae: 0.0256
# Epoch 225/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5116e-04 - mae: 0.0146 - val_loss: 5.8104e-04 - val_mae: 0.0253
# Epoch 226/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5865e-04 - mae: 0.0148 - val_loss: 8.3271e-04 - val_mae: 0.0332
# Epoch 227/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9390e-04 - mae: 0.0159 - val_loss: 6.0799e-04 - val_mae: 0.0267
# Epoch 228/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7196e-04 - mae: 0.0151 - val_loss: 5.6947e-04 - val_mae: 0.0256
# Epoch 229/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1978e-04 - mae: 0.0139 - val_loss: 5.5335e-04 - val_mae: 0.0249
# Epoch 230/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5629e-04 - mae: 0.0146 - val_loss: 5.7354e-04 - val_mae: 0.0256
# Epoch 231/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5475e-04 - mae: 0.0147 - val_loss: 5.5539e-04 - val_mae: 0.0250
# Epoch 232/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5755e-04 - mae: 0.0145 - val_loss: 5.9382e-04 - val_mae: 0.0256
# Epoch 233/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3830e-04 - mae: 0.0145 - val_loss: 5.6714e-04 - val_mae: 0.0256
# Epoch 234/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5136e-04 - mae: 0.0147 - val_loss: 5.5743e-04 - val_mae: 0.0251
# Epoch 235/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8945e-04 - mae: 0.0149 - val_loss: 5.8067e-04 - val_mae: 0.0261
# Epoch 236/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5625e-04 - mae: 0.0147 - val_loss: 6.3515e-04 - val_mae: 0.0277
# Epoch 237/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6188e-04 - mae: 0.0146 - val_loss: 5.5643e-04 - val_mae: 0.0249
# Epoch 238/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8766e-04 - mae: 0.0153 - val_loss: 5.8613e-04 - val_mae: 0.0254
# Epoch 239/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8822e-04 - mae: 0.0148 - val_loss: 7.1280e-04 - val_mae: 0.0283
# Epoch 240/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1997e-04 - mae: 0.0163 - val_loss: 5.9375e-04 - val_mae: 0.0255
# Epoch 241/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8688e-04 - mae: 0.0156 - val_loss: 5.6262e-04 - val_mae: 0.0252
# Epoch 242/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6781e-04 - mae: 0.0145 - val_loss: 5.5232e-04 - val_mae: 0.0251
# Epoch 243/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4867e-04 - mae: 0.0143 - val_loss: 5.5751e-04 - val_mae: 0.0252
# Epoch 244/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6511e-04 - mae: 0.0144 - val_loss: 5.8554e-04 - val_mae: 0.0262
# Epoch 245/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8315e-04 - mae: 0.0152 - val_loss: 5.7423e-04 - val_mae: 0.0257
# Epoch 246/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6758e-04 - mae: 0.0146 - val_loss: 6.8019e-04 - val_mae: 0.0291
# Epoch 247/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9154e-04 - mae: 0.0148 - val_loss: 5.6521e-04 - val_mae: 0.0251
# Epoch 248/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6794e-04 - mae: 0.0146 - val_loss: 6.4917e-04 - val_mae: 0.0267
# Epoch 249/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3789e-04 - mae: 0.0147 - val_loss: 5.6304e-04 - val_mae: 0.0255
# Epoch 250/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6314e-04 - mae: 0.0144 - val_loss: 5.7394e-04 - val_mae: 0.0258
# Epoch 251/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7663e-04 - mae: 0.0152 - val_loss: 5.8387e-04 - val_mae: 0.0262
# Epoch 252/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3745e-04 - mae: 0.0140 - val_loss: 6.9399e-04 - val_mae: 0.0278
# Epoch 253/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6435e-04 - mae: 0.0146 - val_loss: 5.6655e-04 - val_mae: 0.0251
# Epoch 254/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2047e-04 - mae: 0.0136 - val_loss: 5.6443e-04 - val_mae: 0.0256
# Epoch 255/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6676e-04 - mae: 0.0147 - val_loss: 5.4959e-04 - val_mae: 0.0249
# Epoch 256/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7663e-04 - mae: 0.0151 - val_loss: 6.0935e-04 - val_mae: 0.0258
# Epoch 257/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1101e-04 - mae: 0.0158 - val_loss: 5.6005e-04 - val_mae: 0.0253
# Epoch 258/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5706e-04 - mae: 0.0146 - val_loss: 5.4774e-04 - val_mae: 0.0251
# Epoch 259/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7277e-04 - mae: 0.0148 - val_loss: 5.7176e-04 - val_mae: 0.0258
# Epoch 260/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7798e-04 - mae: 0.0149 - val_loss: 5.4983e-04 - val_mae: 0.0248
# Epoch 261/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4815e-04 - mae: 0.0149 - val_loss: 5.6917e-04 - val_mae: 0.0257
# Epoch 262/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3082e-04 - mae: 0.0143 - val_loss: 5.7017e-04 - val_mae: 0.0254
# Epoch 263/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0086e-04 - mae: 0.0158 - val_loss: 5.8214e-04 - val_mae: 0.0260
# Epoch 264/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5754e-04 - mae: 0.0148 - val_loss: 6.4006e-04 - val_mae: 0.0278
# Epoch 265/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0609e-04 - mae: 0.0159 - val_loss: 5.5773e-04 - val_mae: 0.0250
# Epoch 266/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6881e-04 - mae: 0.0145 - val_loss: 5.5655e-04 - val_mae: 0.0250
# Epoch 267/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6659e-04 - mae: 0.0149 - val_loss: 6.4996e-04 - val_mae: 0.0269
# Epoch 268/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5222e-04 - mae: 0.0148 - val_loss: 5.5486e-04 - val_mae: 0.0249
# Epoch 269/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4701e-04 - mae: 0.0141 - val_loss: 5.9299e-04 - val_mae: 0.0264
# Epoch 270/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7439e-04 - mae: 0.0146 - val_loss: 5.8206e-04 - val_mae: 0.0253
# Epoch 271/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3731e-04 - mae: 0.0142 - val_loss: 5.9717e-04 - val_mae: 0.0256
# Epoch 272/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4721e-04 - mae: 0.0144 - val_loss: 5.6440e-04 - val_mae: 0.0257
# Epoch 273/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5578e-04 - mae: 0.0150 - val_loss: 5.9522e-04 - val_mae: 0.0265
# Epoch 274/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7316e-04 - mae: 0.0152 - val_loss: 5.5435e-04 - val_mae: 0.0250
# Epoch 275/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6398e-04 - mae: 0.0144 - val_loss: 5.5292e-04 - val_mae: 0.0249
# Epoch 276/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7532e-04 - mae: 0.0152 - val_loss: 5.8199e-04 - val_mae: 0.0253
# Epoch 277/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3103e-04 - mae: 0.0143 - val_loss: 5.7033e-04 - val_mae: 0.0251
# Epoch 278/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6054e-04 - mae: 0.0145 - val_loss: 5.4763e-04 - val_mae: 0.0248
# Epoch 279/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8474e-04 - mae: 0.0148 - val_loss: 5.6395e-04 - val_mae: 0.0255
# Epoch 280/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2875e-04 - mae: 0.0140 - val_loss: 6.1637e-04 - val_mae: 0.0261
# Epoch 281/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4858e-04 - mae: 0.0149 - val_loss: 6.7238e-04 - val_mae: 0.0273
# Epoch 282/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0584e-04 - mae: 0.0161 - val_loss: 5.5643e-04 - val_mae: 0.0252
# Epoch 283/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6859e-04 - mae: 0.0154 - val_loss: 5.3822e-04 - val_mae: 0.0248
# Epoch 284/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6763e-04 - mae: 0.0151 - val_loss: 6.2970e-04 - val_mae: 0.0276
# Epoch 285/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2638e-04 - mae: 0.0139 - val_loss: 7.9243e-04 - val_mae: 0.0322
# Epoch 286/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7122e-04 - mae: 0.0152 - val_loss: 5.6416e-04 - val_mae: 0.0251
# Epoch 287/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7803e-04 - mae: 0.0148 - val_loss: 5.5281e-04 - val_mae: 0.0247
# Epoch 288/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9212e-04 - mae: 0.0151 - val_loss: 5.9295e-04 - val_mae: 0.0262
# Epoch 289/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4953e-04 - mae: 0.0145 - val_loss: 5.7344e-04 - val_mae: 0.0257
# Epoch 290/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7500e-04 - mae: 0.0150 - val_loss: 6.2011e-04 - val_mae: 0.0273
# Epoch 291/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7298e-04 - mae: 0.0156 - val_loss: 5.7682e-04 - val_mae: 0.0258
# Epoch 292/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7052e-04 - mae: 0.0144 - val_loss: 5.9037e-04 - val_mae: 0.0263
# Epoch 293/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6304e-04 - mae: 0.0148 - val_loss: 5.5343e-04 - val_mae: 0.0248
# Epoch 294/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5577e-04 - mae: 0.0145 - val_loss: 5.7305e-04 - val_mae: 0.0252
# Epoch 295/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4344e-04 - mae: 0.0144 - val_loss: 6.8361e-04 - val_mae: 0.0291
# Epoch 296/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5956e-04 - mae: 0.0144 - val_loss: 6.0129e-04 - val_mae: 0.0268
# Epoch 297/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5125e-04 - mae: 0.0149 - val_loss: 5.5121e-04 - val_mae: 0.0246
# Epoch 298/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6306e-04 - mae: 0.0150 - val_loss: 5.4648e-04 - val_mae: 0.0249
# Epoch 299/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6392e-04 - mae: 0.0151 - val_loss: 5.7764e-04 - val_mae: 0.0259
# Epoch 300/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5374e-04 - mae: 0.0146 - val_loss: 5.5200e-04 - val_mae: 0.0251
# Epoch 301/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6883e-04 - mae: 0.0148 - val_loss: 5.5312e-04 - val_mae: 0.0249
# Epoch 302/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4809e-04 - mae: 0.0143 - val_loss: 5.5859e-04 - val_mae: 0.0254
# Epoch 303/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7077e-04 - mae: 0.0149 - val_loss: 5.7381e-04 - val_mae: 0.0252
# Epoch 304/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2886e-04 - mae: 0.0159 - val_loss: 6.7906e-04 - val_mae: 0.0290
# Epoch 305/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4415e-04 - mae: 0.0144 - val_loss: 6.3194e-04 - val_mae: 0.0264
# Epoch 306/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7816e-04 - mae: 0.0149 - val_loss: 5.6696e-04 - val_mae: 0.0256
# Epoch 307/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7043e-04 - mae: 0.0147 - val_loss: 5.4892e-04 - val_mae: 0.0248
# Epoch 308/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6019e-04 - mae: 0.0143 - val_loss: 6.3767e-04 - val_mae: 0.0278
# Epoch 309/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8141e-04 - mae: 0.0151 - val_loss: 5.7467e-04 - val_mae: 0.0251
# Epoch 310/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7948e-04 - mae: 0.0151 - val_loss: 6.7606e-04 - val_mae: 0.0272
# Epoch 311/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9691e-04 - mae: 0.0160 - val_loss: 5.5664e-04 - val_mae: 0.0251
# Epoch 312/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4164e-04 - mae: 0.0143 - val_loss: 6.5930e-04 - val_mae: 0.0283
# Epoch 313/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4809e-04 - mae: 0.0143 - val_loss: 5.5242e-04 - val_mae: 0.0249
# Epoch 314/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3517e-04 - mae: 0.0144 - val_loss: 7.1813e-04 - val_mae: 0.0301
# Epoch 315/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7933e-04 - mae: 0.0148 - val_loss: 5.5440e-04 - val_mae: 0.0250
# Epoch 316/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4719e-04 - mae: 0.0144 - val_loss: 5.9642e-04 - val_mae: 0.0265
# Epoch 317/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4069e-04 - mae: 0.0141 - val_loss: 5.6128e-04 - val_mae: 0.0250
# Epoch 318/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8299e-04 - mae: 0.0151 - val_loss: 5.8312e-04 - val_mae: 0.0260
# Epoch 319/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4126e-04 - mae: 0.0147 - val_loss: 5.9551e-04 - val_mae: 0.0256
# Epoch 320/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7064e-04 - mae: 0.0155 - val_loss: 5.9744e-04 - val_mae: 0.0256
# Epoch 321/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4601e-04 - mae: 0.0146 - val_loss: 7.0926e-04 - val_mae: 0.0297
# Epoch 322/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6622e-04 - mae: 0.0150 - val_loss: 5.8315e-04 - val_mae: 0.0261
# Epoch 323/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7247e-04 - mae: 0.0146 - val_loss: 5.6559e-04 - val_mae: 0.0250
# Epoch 324/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4511e-04 - mae: 0.0142 - val_loss: 5.6164e-04 - val_mae: 0.0250
# Epoch 325/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9105e-04 - mae: 0.0154 - val_loss: 5.8450e-04 - val_mae: 0.0261
# Epoch 326/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9512e-04 - mae: 0.0156 - val_loss: 5.9297e-04 - val_mae: 0.0263
# Epoch 327/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3786e-04 - mae: 0.0143 - val_loss: 5.7856e-04 - val_mae: 0.0258
# Epoch 328/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3820e-04 - mae: 0.0142 - val_loss: 5.9496e-04 - val_mae: 0.0265
# Epoch 329/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3112e-04 - mae: 0.0140 - val_loss: 6.0186e-04 - val_mae: 0.0267
# Epoch 330/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7052e-04 - mae: 0.0145 - val_loss: 6.4097e-04 - val_mae: 0.0279
# Epoch 331/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6622e-04 - mae: 0.0148 - val_loss: 5.8535e-04 - val_mae: 0.0262
# Epoch 332/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2779e-04 - mae: 0.0161 - val_loss: 5.9157e-04 - val_mae: 0.0265
# Epoch 333/500
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3134e-04 - mae: 0.0143 - val_loss: 5.6061e-04 - val_mae: 0.0255
# <bound method Model.summary of <Sequential name=sequential_5, built=True>>

# %%
model_cnnlstm.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed_15             │ (None, 2, 3, 128)      │           512 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_16             │ (None, 2, 1, 128)      │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_17             │ (None, 2, 128)         │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 50)             │        35,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,091 (426.14 KB)
#  Trainable params: 36,363 (142.04 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 72,728 (284.10 KB)

# %%
# Train and evaluate: loss over epoch
predictor_cnnlstm.plot_loss_by_epoch(history_cnnlstm)

# %%
# Result
y_test_orig_cnnlstm, test_pred_scaled_cnnlstm = predictor_cnnlstm.forecasting_result(model_cnnlstm, X_test_cnnlstm, y_test_cnnlstm)
mae_cnnlstm, rmse_cnnlstm, r2_cnnlstm, mape_cnnlstm = model_metrics(y_test_orig_cnnlstm, test_pred_scaled_cnnlstm)
print(f"MAE: {mae_cnnlstm}, RMSE: {rmse_cnnlstm}, R2: {r2_cnnlstm}, MAPE: {mape_cnnlstm}")
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
# MAE: 8.63582563200755, RMSE: 12.71307816145999, R2: 0.9806052558898685, MAPE: 1.6711981894235752

# %%
predictor_cnnlstm.plot_train_validation_test_forecasting(model_cnnlstm)
# Out:
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step
#
# Training Set Predictions:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step
#
# Validation Set Predictions:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step
#
# Test Set Predictions:

# %% [markdown]
# ## Forecast

# %%
result_df_cnnlstm = create_forecasting_dataframe(df, model_cnnlstm, predictor_cnnlstm, X_train_cnnlstm, X_val_cnnlstm, X_test_cnnlstm)
result_df_cnnlstm
# Out:
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step
#            date  actual  predict_CNNLSTM
# 0    2012-02-07  642.25       643.174011
# 1    2012-02-08  642.50       642.773010
# 2    2012-02-09  637.00       641.365784
# 3    2012-02-10  631.75       639.673889
# 4    2012-02-13  639.50       640.016418
# ...         ...     ...              ...
# 3236 2024-12-25     NaN       310.319611
# 3237 2024-12-26     NaN       310.319611
# 3238 2024-12-27     NaN       310.319611
# 3239 2024-12-30     NaN       310.319611
# 3240 2024-12-31     NaN       310.319611
#
# [3241 rows x 3 columns]

# %%
# Lọc dữ liệu từ năm 2023 trở đi
plot_df = result_df_cnnlstm[(result_df_cnnlstm['date'] >= '2023-01-01') & (result_df_cnnlstm['date'] <= '2024-10-14')]

plt.figure(figsize=(15, 6))

# Vẽ đường thực tế
plt.plot(plot_df['date'], plot_df['actual'], label='Actual', color='blue')

# Vẽ đường dự đoán với màu đỏ
plt.plot(plot_df['date'], plot_df['predict_CNNLSTM'], label='CNN-LSTM forcasting', color='red')

# Thiết lập tiêu đề và nhãn
plt.title("Corn price forecasting (CNN-LSTM)")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # MLP

# %%
class MLPPredictor:
    def __init__(self, n_steps=10, n_features=1):
        self.n_steps = n_steps
        self.n_features = n_features
        self.scaler = MinMaxScaler()
        
    def create_sequences(self, data):
        """Create sequences for MLP input"""
        length = len(data)
        X = np.array([data[i:i+self.n_steps] for i in range(length-self.n_steps)])
        y = np.array([data[i+self.n_steps] for i in range(length-self.n_steps)])
        # Flatten the input for MLP
        return X.reshape((X.shape[0], self.n_steps * self.n_features)), y.ravel()
    
    def prepare_data(self, df, train_size=0.7, val_size=0.15):
        """Prepare and split data into train, validation and test sets"""
        
        # Process date column
        df['date'] = pd.to_datetime(df['date'])
        df = df.sort_values('date')
        
        # Process price column
        prices = df['close'].values.reshape(-1, 1)
        scaled_prices = self.scaler.fit_transform(prices)
        
        X, y = self.create_sequences(scaled_prices)
        
        # Split data
        train_end = int(len(X) * train_size)
        val_end = int(len(X) * (train_size + val_size))
        
        self.X_train, self.y_train = X[:train_end], y[:train_end]
        self.X_val, self.y_val = X[train_end:val_end], y[train_end:val_end]
        self.X_test, self.y_test = X[val_end:], y[val_end:]
        
        self.dates = df['date'].values[self.n_steps:]
        self.train_dates = self.dates[:train_end]
        self.val_dates = self.dates[train_end:val_end]
        self.test_dates = self.dates[val_end:]
        
        return (self.X_train, self.y_train), (self.X_val, self.y_val), (self.X_test, self.y_test)
    
    def build_model(self, hidden_layers=(100, 50), activation='relu', 
                   max_iter=1000, learning_rate_init=0.001):
        """Build sklearn MLPRegressor model"""
        return MLPRegressor(
            hidden_layer_sizes=hidden_layers,
            activation=activation,
            solver='adam',
            max_iter=max_iter,
            learning_rate_init=learning_rate_init,
            random_state=42,
            early_stopping=True,
            validation_fraction=0.1,
            n_iter_no_change=50,
            verbose=True
        )
    
    def evaluate_predictions(self, y_true, y_pred):
        """Calculate various metrics for model evaluation"""
        # Convert predictions back to original scale
        y_true_orig = self.scaler.inverse_transform(y_true.reshape(-1, 1))
        y_pred_orig = self.scaler.inverse_transform(y_pred.reshape(-1, 1))
        
        # Calculate metrics
        mae = mean_absolute_error(y_true_orig, y_pred_orig)
        rmse = root_mean_squared_error(y_true_orig, y_pred_orig)
        r2 = r2_score(y_true_orig, y_pred_orig)
        mape = np.mean(np.abs((y_true_orig - y_pred_orig) / y_true_orig)) * 100
        
        print(f"MAE: {mae:.2f}")
        print(f"RMSE: {rmse:.2f}")
        print(f"R2 Score: {r2:.4f}")
        print(f"MAPE: {mape:.2f}%")
        
        return mae, rmse, r2, mape
    
    def plot_forcasting(self, dates, y_true, y_pred, title):
        """Plot actual vs predicted values"""
        # Convert to original scale
        y_true_orig = self.scaler.inverse_transform(y_true.reshape(-1, 1))
        y_pred_orig = self.scaler.inverse_transform(y_pred.reshape(-1, 1))
        
        plt.figure(figsize=(14, 6))
        plt.plot(dates, y_true_orig, label='Actual', alpha=0.8)
        plt.plot(dates, y_pred_orig, label='Predicted', alpha=0.8)
        plt.title(title)
        plt.xlabel('Date')
        plt.ylabel('Price')
        plt.legend()
        plt.grid(True)
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()
    
    def plot_train_validation_test_forecasting(self, model):
        """Plot and evaluate predictions for all datasets"""
        # Training set
        train_pred = model.predict(self.X_train)
        print("\nTraining Set Metrics:")
        self.evaluate_predictions(self.y_train, train_pred)
        self.plot_forcasting(self.train_dates, self.y_train, train_pred,
                            "Training Set: Actual vs Predicted (MLP)")
        
        # Validation set
        val_pred = model.predict(self.X_val)
        print("\nValidation Set Metrics:")
        self.evaluate_predictions(self.y_val, val_pred)
        self.plot_forcasting(self.val_dates, self.y_val, val_pred,
                            "Validation Set: Actual vs Predicted (MLP)")
        
        # Test set
        test_pred = model.predict(self.X_test)
        print("\nTest Set Metrics:")
        self.evaluate_predictions(self.y_test, test_pred)
        self.plot_forcasting(self.test_dates, self.y_test, test_pred,
                            "Test Set: Actual vs Predicted (MLP)")

    def forecast_future(self, model, last_sequence, n_predictions=30):
        """Dự đoán giá trị tương lai dựa trên sequence cuối cùng"""
        predictions = []
        current_sequence = last_sequence.copy()

        for _ in range(n_predictions):
            # Dự đoán bước tiếp theo
            pred = model.predict(current_sequence.reshape(1, -1))
            predictions.append(pred[0])

            # Chuẩn hóa giá trị dự đoán để đưa vào sequence tiếp theo
            pred_scaled = self.scaler.transform(pred.reshape(-1, 1))
            
            # Dịch sequence sang trái và thêm giá trị dự đoán vào cuối
            current_sequence = np.roll(current_sequence, -1)
            current_sequence[-1] = pred_scaled[0, 0]

        # Chuyển đổi dự đoán về thang đo gốc
        predictions = self.scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
        return predictions

def create_MLP_prediction_dataframe(df, model, predictor, X_train, X_val, X_test):
    # Dự đoán cho các tập train, validation và test
    train_predictions = model.predict(X_train)
    val_predictions = model.predict(X_val)
    test_predictions = model.predict(X_test)

    # Biến đổi ngược lại giá trị dự đoán về thang đo gốc
    train_predictions = predictor.scaler.inverse_transform(train_predictions.reshape(-1, 1))
    val_predictions = predictor.scaler.inverse_transform(val_predictions.reshape(-1, 1))
    test_predictions = predictor.scaler.inverse_transform(test_predictions.reshape(-1, 1))
    
    # Lấy ngày tương ứng với từng tập dữ liệu
    train_dates = predictor.train_dates
    val_dates = predictor.val_dates
    test_dates = predictor.test_dates

    train_df = pd.DataFrame({
        'date': train_dates,
        'actual': df.loc[df['date'].isin(train_dates), 'close'].values,
        'predict_MLP': train_predictions.flatten()
    })
    val_df = pd.DataFrame({
        'date': val_dates,
        'actual': df.loc[df['date'].isin(val_dates), 'close'].values,
        'predict_MLP': val_predictions.flatten()
    })
    test_df = pd.DataFrame({
        'date': test_dates,
        'actual': df.loc[df['date'].isin(test_dates), 'close'].values,
        'predict_MLP': test_predictions.flatten()
    })
    
    # Kết hợp dữ liệu lịch sử
    historical_df = pd.concat([train_df, val_df, test_df], ignore_index=True)

    # Dự đoán cho các ngày tương lai
    last_sequence = X_test[-1]  # Sử dụng sequence cuối cùng trong tập kiểm tra
    future_dates = pd.date_range(start='2024-10-11', end='2024-12-31', freq='B')  # 'B' là ngày làm việc
    future_predictions = predictor.forecast_future(model, last_sequence, len(future_dates))

    # Tạo dataframe cho dự đoán tương lai
    future_df = pd.DataFrame({
        'date': future_dates,
        'actual': np.nan,
        'predict_MLP': future_predictions.flatten()
    })

    # Kết hợp dữ liệu lịch sử và dự đoán tương lai
    result_df = pd.concat([historical_df, future_df], ignore_index=True)
    result_df['date'] = pd.to_datetime(result_df['date'])
    result_df = result_df.sort_values('date').reset_index(drop=True)
    
    return result_df

def MLPforecasting(df, n_steps=10):
    """Main function to train sklearn MLP model and make predictions"""
    predictor = MLPPredictor(n_steps=n_steps)
    
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = predictor.prepare_data(df)
    
    model = predictor.build_model()
    model.fit(X_train, y_train)
    
    # Plot and evaluate results
    predictor.plot_train_validation_test_forecasting(model)
    
    return model, predictor, X_train, y_train, X_val, y_val, X_test, y_test

# %%
model_mlp, predictor_mlp, X_train_mlp, y_train_mlp, X_val_mlp, y_val_mlp, X_test_mlp, y_test_mlp = MLPforecasting(df)
# Out:
# Iteration 1, loss = 0.01303663
# Validation score: 0.972464
# Iteration 2, loss = 0.00105989
# Validation score: 0.950630
# Iteration 3, loss = 0.00078943
# Validation score: 0.983711
# Iteration 4, loss = 0.00057932
# Validation score: 0.984332
# Iteration 5, loss = 0.00047968
# Validation score: 0.984595
# Iteration 6, loss = 0.00040292
# Validation score: 0.989443
# Iteration 7, loss = 0.00035126
# Validation score: 0.990269
# Iteration 8, loss = 0.00035276
# Validation score: 0.989413
# Iteration 9, loss = 0.00030714
# Validation score: 0.991160
# Iteration 10, loss = 0.00028568
# Validation score: 0.991497
# Iteration 11, loss = 0.00027761
# Validation score: 0.991912
# Iteration 12, loss = 0.00027955
# Validation score: 0.992669
# Iteration 13, loss = 0.00024244
# Validation score: 0.993052
# Iteration 14, loss = 0.00024070
# Validation score: 0.993639
# Iteration 15, loss = 0.00023113
# Validation score: 0.992467
# Iteration 16, loss = 0.00023047
# Validation score: 0.993913
# Iteration 17, loss = 0.00021047
# Validation score: 0.994599
# Iteration 18, loss = 0.00021771
# Validation score: 0.993779
# Iteration 19, loss = 0.00020866
# Validation score: 0.994740
# Iteration 20, loss = 0.00021885
# Validation score: 0.993887
# Iteration 21, loss = 0.00020434
# Validation score: 0.993748
# Iteration 22, loss = 0.00020229
# Validation score: 0.994135
# Iteration 23, loss = 0.00020090
# Validation score: 0.994229
# Iteration 24, loss = 0.00019580
# Validation score: 0.994484
# Iteration 25, loss = 0.00019859
# Validation score: 0.995027
# Iteration 26, loss = 0.00021682
# Validation score: 0.993793
# Iteration 27, loss = 0.00020635
# Validation score: 0.994671
# Iteration 28, loss = 0.00019370
# Validation score: 0.992300
# Iteration 29, loss = 0.00026240
# Validation score: 0.991915
# Iteration 30, loss = 0.00026036
# Validation score: 0.989012
# Iteration 31, loss = 0.00022727
# Validation score: 0.993630
# Iteration 32, loss = 0.00019843
# Validation score: 0.994939
# Iteration 33, loss = 0.00019239
# Validation score: 0.994973
# Iteration 34, loss = 0.00018251
# Validation score: 0.994348
# Iteration 35, loss = 0.00018019
# Validation score: 0.994738
# Iteration 36, loss = 0.00018255
# Validation score: 0.994940
# Iteration 37, loss = 0.00018026
# Validation score: 0.994999
# Iteration 38, loss = 0.00018281
# Validation score: 0.994716
# Iteration 39, loss = 0.00017622
# Validation score: 0.995346
# Iteration 40, loss = 0.00017463
# Validation score: 0.994783
# Iteration 41, loss = 0.00017366
# Validation score: 0.995304
# Iteration 42, loss = 0.00017919
# Validation score: 0.994774
# Iteration 43, loss = 0.00017469
# Validation score: 0.993957
# Iteration 44, loss = 0.00019465
# Validation score: 0.994619
# Iteration 45, loss = 0.00019611
# Validation score: 0.993509
# Iteration 46, loss = 0.00021010
# Validation score: 0.994676
# Iteration 47, loss = 0.00018608
# Validation score: 0.995632
# Iteration 48, loss = 0.00017154
# Validation score: 0.995414
# Iteration 49, loss = 0.00020371
# Validation score: 0.992162
# Iteration 50, loss = 0.00019494
# Validation score: 0.995553
# Iteration 51, loss = 0.00017037
# Validation score: 0.994599
# Iteration 52, loss = 0.00017676
# Validation score: 0.995065
# Iteration 53, loss = 0.00018474
# Validation score: 0.991982
# Iteration 54, loss = 0.00018795
# Validation score: 0.995759
# Iteration 55, loss = 0.00017363
# Validation score: 0.995275
# Iteration 56, loss = 0.00018022
# Validation score: 0.995054
# Iteration 57, loss = 0.00016451
# Validation score: 0.995744
# Iteration 58, loss = 0.00017268
# Validation score: 0.994380
# Iteration 59, loss = 0.00020281
# Validation score: 0.993990
# Iteration 60, loss = 0.00021996
# Validation score: 0.992360
# Iteration 61, loss = 0.00020232
# Validation score: 0.995726
# Iteration 62, loss = 0.00016297
# Validation score: 0.995839
# Iteration 63, loss = 0.00016312
# Validation score: 0.994964
# Iteration 64, loss = 0.00016515
# Validation score: 0.995769
# Iteration 65, loss = 0.00016303
# Validation score: 0.995639
# Iteration 66, loss = 0.00017995
# Validation score: 0.994816
# Iteration 67, loss = 0.00018890
# Validation score: 0.996074
# Iteration 68, loss = 0.00018252
# Validation score: 0.995624
# Iteration 69, loss = 0.00017145
# Validation score: 0.994862
# Iteration 70, loss = 0.00016359
# Validation score: 0.996033
# Iteration 71, loss = 0.00017178
# Validation score: 0.994308
# Iteration 72, loss = 0.00016232
# Validation score: 0.995576
# Iteration 73, loss = 0.00017395
# Validation score: 0.994573
# Iteration 74, loss = 0.00015789
# Validation score: 0.967494
# Iteration 75, loss = 0.00079971
# Validation score: 0.988575
# Iteration 76, loss = 0.00033547
# Validation score: 0.985916
# Iteration 77, loss = 0.00025487
# Validation score: 0.995590
# Iteration 78, loss = 0.00018668
# Validation score: 0.994311
# Iteration 79, loss = 0.00017075
# Validation score: 0.995511
# Iteration 80, loss = 0.00016779
# Validation score: 0.995645
# Iteration 81, loss = 0.00016584
# Validation score: 0.995404
# Iteration 82, loss = 0.00015933
# Validation score: 0.995311
# Iteration 83, loss = 0.00015855
# Validation score: 0.994585
# Iteration 84, loss = 0.00017130
# Validation score: 0.995562
# Iteration 85, loss = 0.00015872
# Validation score: 0.995725
# Iteration 86, loss = 0.00015591
# Validation score: 0.995971
# Iteration 87, loss = 0.00016040
# Validation score: 0.995266
# Iteration 88, loss = 0.00015886
# Validation score: 0.995289
# Iteration 89, loss = 0.00015907
# Validation score: 0.995957
# Iteration 90, loss = 0.00015420
# Validation score: 0.995271
# Iteration 91, loss = 0.00015559
# Validation score: 0.995630
# Iteration 92, loss = 0.00015639
# Validation score: 0.994715
# Iteration 93, loss = 0.00016103
# Validation score: 0.996064
# Iteration 94, loss = 0.00016745
# Validation score: 0.995822
# Iteration 95, loss = 0.00015586
# Validation score: 0.995812
# Iteration 96, loss = 0.00016781
# Validation score: 0.995768
# Iteration 97, loss = 0.00015882
# Validation score: 0.995094
# Iteration 98, loss = 0.00016055
# Validation score: 0.993780
# Iteration 99, loss = 0.00019049
# Validation score: 0.995507
# Iteration 100, loss = 0.00015701
# Validation score: 0.995256
# Iteration 101, loss = 0.00015673
# Validation score: 0.996162
# Iteration 102, loss = 0.00016247
# Validation score: 0.995802
# Iteration 103, loss = 0.00015957
# Validation score: 0.994170
# Iteration 104, loss = 0.00016850
# Validation score: 0.995831
# Iteration 105, loss = 0.00016488
# Validation score: 0.993939
# Iteration 106, loss = 0.00017215
# Validation score: 0.996164
# Iteration 107, loss = 0.00016529
# Validation score: 0.995902
# Iteration 108, loss = 0.00015701
# Validation score: 0.996158
# Iteration 109, loss = 0.00015780
# Validation score: 0.995137
# Iteration 110, loss = 0.00015847
# Validation score: 0.995558
# Iteration 111, loss = 0.00016242
# Validation score: 0.994989
# Iteration 112, loss = 0.00016323
# Validation score: 0.995093
# Iteration 113, loss = 0.00015983
# Validation score: 0.994752
# Iteration 114, loss = 0.00016048
# Validation score: 0.995464
# Iteration 115, loss = 0.00015247
# Validation score: 0.995091
# Iteration 116, loss = 0.00015710
# Validation score: 0.996145
# Iteration 117, loss = 0.00015024
# Validation score: 0.995625
# Iteration 118, loss = 0.00015357
# Validation score: 0.995824
# Validation score did not improve more than tol=0.000100 for 50 consecutive epochs. Stopping.
#
# Training Set Metrics:
# MAE: 5.64
# RMSE: 9.18
# R2 Score: 0.9940
# MAPE: 1.23%
# Validation Set Metrics:
# MAE: 11.38
# RMSE: 14.68
# R2 Score: 0.9687
# MAPE: 1.82%
# Test Set Metrics:
# MAE: 7.07
# RMSE: 9.77
# R2 Score: 0.9886
# MAPE: 1.35%

# %%
y_pred_test_mlp = model_mlp.predict(X_test_mlp)

mae_mlp, rmse_mlp, r2_mlp, mape_mlp = predictor_mlp.evaluate_predictions(y_test_mlp, y_pred_test_mlp)
# Out:
# MAE: 7.07
# RMSE: 9.77
# R2 Score: 0.9886
# MAPE: 1.35%

# %%
result_df_mlp = create_MLP_prediction_dataframe(df, model_mlp, predictor_mlp, X_train_mlp, X_val_mlp, X_test_mlp)
result_df_mlp
# Out:
#            date  actual  predict_MLP
# 0    2012-02-07  642.25   636.252208
# 1    2012-02-08  642.50   634.694919
# 2    2012-02-09  637.00   635.356031
# 3    2012-02-10  631.75   631.905108
# 4    2012-02-13  639.50   626.944378
# ...         ...     ...          ...
# 3236 2024-12-25     NaN   234.178643
# 3237 2024-12-26     NaN   234.178643
# 3238 2024-12-27     NaN   234.178643
# 3239 2024-12-30     NaN   234.178643
# 3240 2024-12-31     NaN   234.178643
#
# [3241 rows x 3 columns]

# %%
# Lọc dữ liệu từ năm 2023 trở đi
plot_df = result_df_mlp[(result_df_mlp['date'] >= '2023-01-01') & (result_df_mlp['date'] <= '2024-10-13')]

plt.figure(figsize=(15, 6))

# Vẽ đường thực tế
plt.plot(plot_df['date'], plot_df['actual'], label='Actual', color='blue')

# Vẽ đường dự đoán với màu đỏ
plt.plot(plot_df['date'], plot_df['predict_MLP'], label='MLP forcasting', color='red')

# Thiết lập tiêu đề và nhãn
plt.title("Corn price forecasting (MLP)")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # KNN

# %%
class KNNPredictor:
    def __init__(self, n_steps=10, n_neighbors=5):
        self.n_steps = n_steps
        self.n_neighbors = n_neighbors
        self.scaler = MinMaxScaler()
        
    def create_sequences(self, data):
        """Create sequences from time series data"""
        X, y = [], []
        for i in range(len(data) - self.n_steps):
            X.append(data[i:(i + self.n_steps), 0])
            y.append(data[i + self.n_steps, 0])
        return np.array(X), np.array(y)
    
    def prepare_data(self, df, train_size=0.7, val_size=0.15):
        """Prepare and split data into train, validation and test sets"""
        
        # Process date column
        df['date'] = pd.to_datetime(df['date'])
        df = df.sort_values('date')
        
        # Process price column
        prices = df['close'].values.reshape(-1, 1)
        scaled_prices = self.scaler.fit_transform(prices)
        
        # Create sequences
        X, y = self.create_sequences(scaled_prices)
        
        # Split data into train, validation, test sets
        train_end = int(len(X) * train_size)
        val_end = int(len(X) * (train_size + val_size))
        
        self.X_train, self.y_train = X[:train_end], y[:train_end]
        self.X_val, self.y_val = X[train_end:val_end], y[train_end:val_end]
        self.X_test, self.y_test = X[val_end:], y[val_end:]
        
        # Store dates for plotting
        self.dates = df['date'].values[self.n_steps:]
        self.train_dates = self.dates[:train_end]
        self.val_dates = self.dates[train_end:val_end]
        self.test_dates = self.dates[val_end:]
        
        return (self.X_train, self.y_train), (self.X_val, self.y_val), (self.X_test, self.y_test)

    def build_model(self, weights='uniform', algorithm='auto', leaf_size=30):
        """Build KNN model with given parameters"""
        model = KNeighborsRegressor(
            n_neighbors=self.n_neighbors,
            weights=weights,
            algorithm=algorithm,
            leaf_size=leaf_size
        )
        return model
    
    def train_model(self, model, X_train, y_train):
        history = model.fit(X_train, y_train)
        return history
    
    def evaluate_model(self, model, X, y):
        """Evaluate model performance"""
        # Make predictions
        predictions = model.predict(X)
        
        # Convert predictions and actual values back to original scale
        actual = self.scaler.inverse_transform(y.reshape(-1, 1))
        predictions = self.scaler.inverse_transform(predictions.reshape(-1, 1))
        
        mae = mean_absolute_error(actual, predictions)
        rmse = root_mean_squared_error(actual, predictions)
        r2 = r2_score(actual, predictions)
        mape = mean_absolute_percentage_error(actual, predictions)

        return actual, predictions, {'mae': mae, 'rmse': rmse, 'r2': r2, 'mape': mape}
    
    def plot_forcasting(self, dates, y_true, y_pred, title='Model Predictions vs Actual Values'):
        """Plot predictions against actual values with dates"""
        plt.figure(figsize=(15, 6))
        plt.plot(dates, y_true, label='Actual', color='blue')
        plt.plot(dates, y_pred, label='Predicted', color='red', alpha=0.7)
        
        plt.title(title)
        plt.xlabel('Date')
        plt.ylabel('Price')
        plt.legend()
        plt.grid(True)
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()

    def plot_train_validation_test_forecasting(self, model):
        """Plot predictions for all datasets"""
        # Training set
        y_train_orig, train_pred, train_metrics = self.evaluate_model(model, self.X_train, self.y_train)
        print("\nTraining Set Metrics:")
        print(f"RMSE: {train_metrics['rmse']:.2f}")
        print(f"MAE: {train_metrics['mae']:.2f}")
        self.plot_forcasting(self.train_dates, y_train_orig, train_pred, 
                            "Training Set: Actual vs Predicted")
        
        # Validation set
        y_val_orig, val_pred, val_metrics = self.evaluate_model(model, self.X_val, self.y_val)
        print("\nValidation Set Metrics:")
        print(f"RMSE: {val_metrics['rmse']:.2f}")
        print(f"MAE: {val_metrics['mae']:.2f}")
        self.plot_forcasting(self.val_dates, y_val_orig, val_pred,
                            "Validation Set: Actual vs Predicted")
        
        # Test set
        y_test_orig, test_pred, test_metrics = self.evaluate_model(model, self.X_test, self.y_test)
        print("\nTest Set Metrics:")
        print(f"RMSE: {test_metrics['rmse']:.2f}")
        print(f"MAE: {test_metrics['mae']:.2f}")
        self.plot_forcasting(self.test_dates, y_test_orig, test_pred,
                            "Test Set: Actual vs Predicted")
    
    def forecast_future(self, model, last_sequence, n_predictions=30):
        """Make future predictions using the trained model"""
        predictions = []
        current_sequence = last_sequence.copy()
        
        for _ in range(n_predictions):
            # Make prediction
            pred = model.predict(current_sequence.reshape(1, -1))
            predictions.append(pred[0])
            
            # Update sequence: remove first element and append prediction
            current_sequence = np.roll(current_sequence, -1)
            current_sequence[-1] = pred
            
        # Convert predictions back to original scale
        predictions = self.scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
        return predictions

def create_forecasting_dataframe(df, model, predictor, X_train, X_val, X_test):
    """Create a DataFrame containing all predictions"""
    # Make predictions
    _, train_predictions, _ = predictor.evaluate_model(model, X_train, predictor.y_train)
    _, val_predictions, _ = predictor.evaluate_model(model, X_val, predictor.y_val)
    _, test_predictions, _ = predictor.evaluate_model(model, X_test, predictor.y_test)
    
    # Create DataFrames for historical data
    train_df = pd.DataFrame({
        'date': predictor.train_dates,
        'actual': df.loc[df['date'].isin(predictor.train_dates), 'close'].values,
        'predict_KNN': train_predictions.flatten()
    })
    
    val_df = pd.DataFrame({
        'date': predictor.val_dates,
        'actual': df.loc[df['date'].isin(predictor.val_dates), 'close'].values,
        'predict_KNN': val_predictions.flatten()
    })
    
    test_df = pd.DataFrame({
        'date': predictor.test_dates,
        'actual': df.loc[df['date'].isin(predictor.test_dates), 'close'].values,
        'predict_KNN': test_predictions.flatten()
    })
    
    historical_df = pd.concat([train_df, val_df, test_df], ignore_index=True)
    
    # Make future predictions
    last_sequence = X_test[-1]
    future_dates = pd.date_range(start='2024-10-11', end='2024-12-31', freq='B')
    future_predictions = predictor.forecast_future(model, last_sequence, len(future_dates))
    
    future_df = pd.DataFrame({
        'date': future_dates,
        'actual': np.nan,
        'predict_KNN': future_predictions.flatten()
    })
    
    # Combine historical and future predictions
    result_df = pd.concat([historical_df, future_df], ignore_index=True)
    result_df['date'] = pd.to_datetime(result_df['date'])
    result_df = result_df.sort_values('date').reset_index(drop=True)
    
    return result_df

def KNNforecasting(df, n_steps=30, n_neighbors=5):
    """Main function to train model and make predictions"""
    predictor = KNNPredictor(n_steps=n_steps, n_neighbors=n_neighbors)
    
    # Prepare data
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = predictor.prepare_data(df)
    
    # Build and train model
    model = predictor.build_model()
    history = predictor.train_model(model, X_train, y_train)
    
    return model, predictor, history, X_train, y_train, X_val, y_val, X_test, y_test

# %%
model_knn, predictor_knn, history_knn, X_train_knn, y_train_knn, X_val_knn, y_val_knn, X_test_knn, y_test_knn = KNNforecasting(df, n_steps=10, n_neighbors=5)

# Xem kết quả
predictor_knn.plot_train_validation_test_forecasting(model_knn)

# Tạo DataFrame dự đoán
results_df_knn = create_forecasting_dataframe(df, model_knn, predictor_knn, X_train_knn, X_val_knn, X_test_knn)
# Out:
# Training Set Metrics:
# RMSE: 8.18
# MAE: 4.94
# Validation Set Metrics:
# RMSE: 20.43
# MAE: 16.41
# Test Set Metrics:
# RMSE: 15.40
# MAE: 10.87

# %%
actual_knn, predictions_knn, metrics = predictor_knn.evaluate_model(model_knn, X_test_knn, y_test_knn)

# %%
mae_knn = metrics['mae']
rmse_knn = metrics['rmse']
r2_knn = metrics['r2']
mape_knn = metrics['mape']

# %%
# Lọc dữ liệu từ năm 2023 trở đi
plot_df = results_df_knn[(result_df_mlp['date'] >= '2023-01-01') & (results_df_knn['date'] <= '2024-12-31')]

plt.figure(figsize=(15, 6))

# Vẽ đường thực tế
plt.plot(plot_df['date'], plot_df['actual'], label='Actual', color='blue')

# Vẽ đường dự đoán với màu đỏ
plt.plot(plot_df['date'], plot_df['predict_KNN'], label='KNN forcasting', color='red')

# Thiết lập tiêu đề và nhãn
plt.title("Corn price forecasting (KNN)")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Comparison

# %%
result_df_cnnlstm = result_df_cnnlstm[(result_df_cnnlstm['date'] >= '2023-01-01') & (result_df_cnnlstm['date'] <= '2024-10-14')]
result_df_mlp = result_df_mlp[(result_df_mlp['date'] >= '2023-01-01') & (result_df_mlp['date'] <= '2024-10-13')]

# %%
result = pd.concat([result_df_cnnlstm, result_df_mlp, results_df_knn], axis = 1)
result = result.loc[:, ~result.columns.duplicated()]
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3241 entries, 2736 to 3240
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             449 non-null    datetime64[ns]
#  1   actual           447 non-null    float64
#  2   predict_CNNLSTM  449 non-null    float32
#  3   predict_MLP      448 non-null    float64
#  4   predict_KNN      3241 non-null   float64
# dtypes: datetime64[ns](1), float32(1), float64(3)
# memory usage: 139.3 KB

# %%
plt.figure(figsize=(14, 7))

plt.plot(result['date'], result['actual'], label='Actual', color='black', alpha=0.7)

plt.plot(result['date'], result['predict_CNNLSTM'], label='Predicted CNN-LSTM', color='blue', alpha=0.6)
plt.plot(result['date'], result['predict_MLP'], label='Predicted MLP', color='orange', alpha=0.6)
plt.plot(result['date'], result['predict_KNN'], label='Predicted KNN', color='green', alpha=0.6)

plt.title('Actual vs Predicted Values', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Values', fontsize=14)
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
metrics_data = {
    'Model': ['CNN-LSTM', 'KNN', 'MLP'],
    'MAE': [mae_cnnlstm, mae_knn, mae_mlp],
    'RMSE': [rmse_cnnlstm, rmse_knn, rmse_mlp],
    'R²': [r2_cnnlstm, r2_knn, r2_mlp],
    'MAPE': [mape_cnnlstm, mape_knn, mape_mlp]
}

metrics_df = pd.DataFrame(metrics_data)

metrics_df.set_index('Model', inplace=True)

metrics_df
# Out:
#                 MAE       RMSE        R²      MAPE
# Model
# CNN-LSTM   8.635826  12.713078  0.980605  1.671198
# KNN       10.866004  15.402998  0.971530  0.020323
# MLP        7.070881   9.767014  0.988553  1.349183
